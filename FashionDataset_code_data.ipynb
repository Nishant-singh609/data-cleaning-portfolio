# %%
import numpy as np
import pandas as pd
import matplotlib as plt
data=pd.read_csv("Before_cleaning_FashionDataset.csv")

# %%
data
# Out:
#        Unnamed: 0    BrandName  \
# 0               0         life
# 1               1         only
# 2               2      fratini
# 3               3  zink london
# 4               4         life
# ...           ...          ...
# 30753          21    swarovski
# 30754          22          Nan
# 30755          23       jewelz
# 30756          24      estelle
# 30757          25      estelle
#
#                                                  Deatils  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 30753            crystal stylish womens rodhium earrings
# 30754                                                Nan
# 30755                 ethnic gold plated jhumki earrings
# ...

# %%
data.head(5)
# Out:
#    Unnamed: 0    BrandName                                            Deatils  \
# 0           0         life  solid cotton blend collar neck womens a-line d...
# 1           1         only  polyester peter pan collar womens blouson dres...
# 2           2      fratini  solid polyester blend wide neck womens regular...
# 3           3  zink london  stripes polyester sweetheart neck womens dress...
# 4           4         life  regular fit regular length denim womens jeans ...
#
#                                      Sizes       MRP SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                         Size:34,36,38,40  Rs\n3499      2449  30% off
# 2              Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3          Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                   Size:26,28,30,32,34,36  Rs\n1699       849  50% off
#
#             Category
# 0  Westernwear-Women
# ...

# %%
data.tail(4)
# Out:
#        Unnamed: 0 BrandName  \
# 30754          22       Nan
# 30755          23    jewelz
# 30756          24   estelle
# 30757          25   estelle
#
#                                                  Deatils Sizes       MRP  \
# 30754                                                Nan   Nan       Nan
# 30755                 ethnic gold plated jhumki earrings   Nan  Rs\n1839
# 30756  womens gold plated double line fancy white and...   Nan       Nan
# 30757  womens gold plated bridge designer mangalsutra...   Nan       Nan
#
#       SellPrice Discount         Category
# 30754       Nan      Nan  Jewellery-Women
# 30755       643  65% off  Jewellery-Women
# 30756      2799      Nan  Jewellery-Women
# 30757      1899      Nan  Jewellery-Women

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30758 entries, 0 to 30757
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  30758 non-null  int64
#  1   BrandName   30758 non-null  object
#  2   Deatils     30758 non-null  object
#  3   Sizes       30758 non-null  object
#  4   MRP         30758 non-null  object
#  5   SellPrice   30758 non-null  object
#  6   Discount    30758 non-null  object
#  7   Category    30758 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.9+ MB

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# BrandName     0
# Deatils       0
# Sizes         0
# MRP           0
# SellPrice     0
# Discount      0
# Category      0
# dtype: int64

# %%
data.drop_duplicates(inplace=True)
# first of remove the duplicate vaues

# %%
data
# Out:
#        Unnamed: 0           BrandName  \
# 0               0                life
# 1               1                only
# 2               2             fratini
# 3               3         zink london
# 4               4                life
# ...           ...                 ...
# 30752          20  shaya by caratlane
# 30753          21           swarovski
# 30755          23              jewelz
# 30756          24             estelle
# 30757          25             estelle
#
#                                                  Deatils  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 30752               the wing woman clover charm necklace
# ...

# %%
data.duplicated().sum() # to remove the all duplicate value
# Out:
# np.int64(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29427 entries, 0 to 30757
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  29427 non-null  int64
#  1   BrandName   29427 non-null  object
#  2   Deatils     29427 non-null  object
#  3   Sizes       29427 non-null  object
#  4   MRP         29427 non-null  object
#  5   SellPrice   29427 non-null  object
#  6   Discount    29427 non-null  object
#  7   Category    29427 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.0+ MB

# %%
data.columns # who to change the columns name in the perticular row:
# Out:
# Index(['Unnamed: 0', 'BrandName', 'Deatils', 'Sizes', 'MRP', 'SellPrice',
#        'Discount', 'Category'],
#       dtype='object')

# %%
data.rename(columns={'Unnamed: 0' :'S_no'},inplace=True)

# %%
data.columns
# Out:
# Index(['S_no', 'BrandName', 'Deatils', 'Sizes', 'MRP', 'SellPrice', 'Discount',
#        'Category'],
#       dtype='object')

# %%
data.rename(columns={'BrandName' :'Brand_Name'},inplace=True)

# %%
data.rename(columns={'SellPrice' :'Sell_Price'},inplace=True)

# %%
data.columns
# Out:
# Index(['S_no', 'Brand_Name', 'Deatils', 'Sizes', 'MRP', 'Sell_Price',
#        'Discount', 'Category'],
#       dtype='object')

# %%
 # the all columns convet into the capitilize form
data1=[]
for i in data.columns:
    data1.append(i.upper())

# %%
# the copy data
new_data=data.copy()

# %%
new_data.columns=data1

# %%
new_data
# Out:
#        S_NO          BRAND_NAME  \
# 0         0                life
# 1         1                only
# 2         2             fratini
# 3         3         zink london
# 4         4                life
# ...     ...                 ...
# 30752    20  shaya by caratlane
# 30753    21           swarovski
# 30755    23              jewelz
# 30756    24             estelle
# 30757    25             estelle
#
#                                                  DEATILS  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 30752               the wing woman clover charm necklace
# 30753            crystal stylish womens rodhium earrings
# ...

# %%
data=new_data

# %%
data
# Out:
#        S_NO          BRAND_NAME  \
# 0         0                life
# 1         1                only
# 2         2             fratini
# 3         3         zink london
# 4         4                life
# ...     ...                 ...
# 30752    20  shaya by caratlane
# 30753    21           swarovski
# 30755    23              jewelz
# 30756    24             estelle
# 30757    25             estelle
#
#                                                  DEATILS  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 30752               the wing woman clover charm necklace
# 30753            crystal stylish womens rodhium earrings
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29427 entries, 0 to 30757
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S_NO        29427 non-null  int64
#  1   BRAND_NAME  29427 non-null  object
#  2   DEATILS     29427 non-null  object
#  3   SIZES       29427 non-null  object
#  4   MRP         29427 non-null  object
#  5   SELL_PRICE  29427 non-null  object
#  6   DISCOUNT    29427 non-null  object
#  7   CATEGORY    29427 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.0+ MB

# %%
data.isnull().sum()
# Out:
# S_NO          0
# BRAND_NAME    0
# DEATILS       0
# SIZES         0
# MRP           0
# SELL_PRICE    0
# DISCOUNT      0
# CATEGORY      0
# dtype: int64

# %%
con=0
data["BRAND_NAME"]
for i in data["BRAND_NAME"]:
    if(i=='Nan'):
        con=con+1
print(con)
# Out:
# 7

# %%
data["BRAND_NAME"].value_counts().iloc[174:190]
# Out:
# BRAND_NAME
# moschino               8
# colour me              7
# yves saint laurent     7
# nike                   7
# Nan                    7
# duke                   7
# real effect            7
# elizabeth arden        6
# yves rocher            6
# embark                 6
# stoln accessories      5
# abercrombie & fitch    5
# marc jacobs            5
# xylys                  5
# havaianas              5
# estee lauder           5
# Name: count, dtype: int64

# %%
# to drop the Nan value
data["BRAND_NAME"] = data["BRAND_NAME"].replace("Nan", np.nan)

# %%
data.isnull().sum()
# Out:
# S_NO          0
# BRAND_NAME    7
# DEATILS       0
# SIZES         0
# MRP           0
# SELL_PRICE    0
# DISCOUNT      0
# CATEGORY      0
# dtype: int64

# %%
data["BRAND_NAME"].isnull().sum()
# Out:
# np.int64(7)

# %%
 # to remove the null value 
data.dropna(subset=["BRAND_NAME"],inplace=True)

# %%
data.isnull().sum()
# Out:
# S_NO          0
# BRAND_NAME    0
# DEATILS       0
# SIZES         0
# MRP           0
# SELL_PRICE    0
# DISCOUNT      0
# CATEGORY      0
# dtype: int64

# %%
 # knw i am working in the in the columns data["DEATILS"]

# %%
data["DEATILS"].value_counts()
# Out:
# DEATILS
# synthetic womens casual sandals - black                                                                     35
# alloy metal gold color western womens earrings                                                              27
# solid zari silk blend festive wear womens regular saree - black                                             24
# structured zari silk blend festive wear womens regular saree - green                                        24
# structured zari silk blend festive wear womens regular saree - pink                                         23
#                                                                                                             ..
# the wing woman clover charm necklace                                                                         1
# sterling silver oval turquoise ear studs                                                                     1
# ...

# %%
con=0
data["DEATILS"]
for i in data["DEATILS"]:
    if(i=='Nan'):
        con=con+1
print(con) 
 #the columns no present in the Nan value
# Out:
# 0

# %%
 # know i am working the columns name  data["SIZES"]

# %%
data["SIZES"].head(90)
# Out:
# 0     Size:Large,Medium,Small,X-Large,X-Small
# 1                            Size:34,36,38,40
# 2                 Size:Large,X-Large,XX-Large
# 3             Size:Large,Medium,Small,X-Large
# 4                      Size:26,28,30,32,34,36
#                        ...
# 88                        Size:10,12,14,16,18
# 89          Size:Large,Medium,X-Large,X-Small
# 90                              Size:28,30,32
# 91            Size:Large,Medium,Small,X-Small
# 92                     Size:26,28,30,32,34,36
# Name: SIZES, Length: 90, dtype: object

# %%
data["SIZES"].tail(90) # the Nan value I thing fill in the string formate that why not showing in the Nan value
# Out:
# 30663    Nan
# 30664    Nan
# 30665    Nan
# 30666    Nan
# 30667    Nan
#         ...
# 30752    Nan
# 30753    Nan
# 30755    Nan
# 30756    Nan
# 30757    Nan
# Name: SIZES, Length: 90, dtype: object

# %%
data["SIZES"].value_counts()
# Out:
# SIZES
# Nan                                                                                   6194
# Size:Large,Medium,Small,X-Large,X-Small                                               1970
# Size:Large,Medium,Small,X-Large                                                       1615
# Size:Large,Medium,Small,X-Large,X-Small,XX-Large                                      1505
# Size:Large,Medium,Small,X-Large,XX-Large                                              1441
#                                                                                       ...
# Size:35,36,38                                                                            1
# Size:35,36,38,39                                                                         1
# Size:3,8                                                                                 1
# Size:36,41                                                                               1
# ...

# %%
count=0
for i in data["SIZES"]:
    if(i=="Nan"):
        count+=1
print(count)
# Out:
# 6194

# %%
data["SIZES"].isnull().sum()
# Out:
# np.int64(0)

# %%
data["SIZES"]=data["SIZES"].replace("Nan",np.nan)

# %%
data["SIZES"].isnull().sum()
# Out:
# np.int64(6194)

# %%
data.isnull().sum()
# Out:
# S_NO             0
# BRAND_NAME       0
# DEATILS          0
# SIZES         6194
# MRP              0
# SELL_PRICE       0
# DISCOUNT         0
# CATEGORY         0
# dtype: int64

# %%
print(data["SIZES"].value_counts().median())
print(data["SIZES"].value_counts().mean())
print(data["SIZES"].value_counts().mode())
# Out:
# 2.0
# 19.834329632792485
# 0    1
# Name: count, dtype: int64

# %%
# to fill the data in the null value
data["SIZES"].value_counts()
# Out:
# SIZES
# Size:Large,Medium,Small,X-Large,X-Small               1970
# Size:Large,Medium,Small,X-Large                       1615
# Size:Large,Medium,Small,X-Large,X-Small,XX-Large      1505
# Size:Large,Medium,Small,X-Large,XX-Large              1441
# Size:Large,Medium,Small,X-Large,XX-Large,XXX-Large     738
#                                                       ...
# Size:35,36,37,38,40                                      1
# Size:2,3,4,6                                             1
# Size:5,6,11                                              1
# Size:3,4,6                                               1
# Size:7.5,8.5                                             1
# Name: count, Length: 1171, dtype: int64

# %%
data["SIZES"].value_counts().iloc[100:50]
# Out:
# Series([], Name: count, dtype: int64)

# %%
data["SIZES"].isnull().sum()
# Out:
# np.int64(6194)

# %%
data["SIZES"]=data["SIZES"].fillna("Size:Large,Medium,X-Large,X-Small,XX-Large")

# %%
data.isnull().sum()
# Out:
# S_NO          0
# BRAND_NAME    0
# DEATILS       0
# SIZES         0
# MRP           0
# SELL_PRICE    0
# DISCOUNT      0
# CATEGORY      0
# dtype: int64

# %%
# know i am working in the columns data["MRP"]

# %%
data["MRP"].isnull().sum()
# Out:
# np.int64(0)

# %%
cout=0
for i in data["MRP"]:
    if(i=="Nan"):
        cout=cout+1
print(cout)
# Out:
# 7007

# %%
#  3 the columns data inthe given in the Nan value  the first convert into the 0 form so convert the nan

# %%
data["MRP"]=data["MRP"].str.replace("Nan" ,"949")

# %%
data["MRP"].isnull().sum()
# Out:
# np.int64(0)

# %%
data["MRP"].value_counts()
# Out:
# MRP
# 949          7007
# Rs\n1499      925
# Rs\n1999      918
# Rs\n999       876
# Rs\n1299      854
#              ...
# Rs\n12100       1
# Rs\n17300       1
# Rs\n5100        1
# Rs\n680         1
# Rs\n1059        1
# Name: count, Length: 1097, dtype: int64

# %%
data["MRP"]
# Out:
# 0        Rs\n1699
# 1        Rs\n3499
# 2        Rs\n1199
# 3        Rs\n2299
# 4        Rs\n1699
#            ...
# 30752         949
# 30753         949
# 30755    Rs\n1839
# 30756         949
# 30757         949
# Name: MRP, Length: 29420, dtype: object

# %%
data["MRP"].value_counts()
# Out:
# MRP
# 949          7007
# Rs\n1499      925
# Rs\n1999      918
# Rs\n999       876
# Rs\n1299      854
#              ...
# Rs\n12100       1
# Rs\n17300       1
# Rs\n5100        1
# Rs\n680         1
# Rs\n1059        1
# Name: count, Length: 1097, dtype: int64

# %%
data["MRP"].value_counts()
print(data["MRP"][4])
# Out:
# Rs
# 1699

# %%
data["MRP"]=data["MRP"].str.replace("Rs\n","",regex=False)

# %%
data["MRP"]=data["MRP"].fillna("0")

# %%
print(data["MRP"].value_counts().mean())
print(data["MRP"].value_counts().median())
print(data["MRP"].value_counts().median())
# Out:
# 26.843065693430656
# 2.0
# 2.0

# %%
data["MRP"].value_counts().iloc[110:130]
# Out:
# MRP
# 1298    28
# 7500    28
# 9495    27
# 3700    27
# 3495    27
# 849     26
# 3990    26
# 2195    26
# 1300    26
# 5495    25
# 1294    24
# 1494    24
# 2890    24
# 4199    24
# 6995    24
# 1590    23
# 398     23
# 4495    23
# 1150    23
# 6499    23
# Name: count, dtype: int64

# %%
data["MRP"].value_counts()
# Out:
# MRP
# 949      7033
# 1499      925
# 1999      918
# 999       876
# 1299      854
#          ...
# 12100       1
# 17300       1
# 5100        1
# 680         1
# 1059        1
# Name: count, Length: 1096, dtype: int64

# %%
data["MRP"][8] # to type convertion of the data
# Out:
# np.int64(2099)

# %%
data["MRP"]=data["MRP"].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29420 entries, 0 to 30757
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S_NO        29420 non-null  int64
#  1   BRAND_NAME  29420 non-null  object
#  2   DEATILS     29420 non-null  object
#  3   SIZES       29420 non-null  object
#  4   MRP         29420 non-null  int64
#  5   SELL_PRICE  29420 non-null  object
#  6   DISCOUNT    29420 non-null  object
#  7   CATEGORY    29420 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.0+ MB

# %%
data["SELL_PRICE"].head(20)
# Out:
# 0      849
# 1     2449
# 2      599
# 3     1379
# 4      849
# 5     1615
# 6      649
# 7      649
# 8      839
# 9      599
# 10     749
# 11     499
# 12     749
# 13     299
# 14     499
# 15     599
# 16     299
# 17     649
# 18     799
# 19     999
# Name: SELL_PRICE, dtype: object

# %%
data["SELL_PRICE"].tail(20)
# Out:
# 30737    4199
# 30738    1699
# 30739    2089
# 30740     149
# 30741    2564
# 30742    4195
# 30743    1614
# 30744     424
# 30745    1299
# 30746     608
# 30747     399
# 30748     468
# 30749     381
# 30750    1030
# 30751    8950
# 30752    1250
# 30753    8950
# 30755     643
# 30756    2799
# 30757    1899
# Name: SELL_PRICE, dtype: object

# %%
data["SELL_PRICE"].value_counts()
# Out:
# SELL_PRICE
# 499      798
# 999      780
# 599      668
# 899      609
# 799      601
#         ...
# 5515       1
# 7700       1
# 6413       1
# 3059       1
# 15500      1
# Name: count, Length: 2045, dtype: int64

# %%
type(data["SELL_PRICE"][9])
# Out:
# str

# %%
count=0
for i in data["SELL_PRICE"]:
    if(i=="Nan"):
        count=count+1
print(count)
# Out:
# 0

# %%
data["SELL_PRICE"]=data["SELL_PRICE"].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29420 entries, 0 to 30757
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S_NO        29420 non-null  int64
#  1   BRAND_NAME  29420 non-null  object
#  2   DEATILS     29420 non-null  object
#  3   SIZES       29420 non-null  object
#  4   MRP         29420 non-null  int64
#  5   SELL_PRICE  29420 non-null  int64
#  6   DISCOUNT    29420 non-null  object
#  7   CATEGORY    29420 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 3.0+ MB

# %%
# know i am working in the columns data["DISCOUNT"]

# %%
data["DISCOUNT"]
# Out:
# 0        50% off
# 1        30% off
# 2        50% off
# 3        40% off
# 4        50% off
#           ...
# 30752        Nan
# 30753        Nan
# 30755    65% off
# 30756        Nan
# 30757        Nan
# Name: DISCOUNT, Length: 29420, dtype: object

# %%
data["DISCOUNT"].isnull().sum()
# Out:
# np.int64(0)

# %%
count=0
for i in data["DISCOUNT"]:
    if(i=="Nan"):
        count=count+1
print(count)
# Out:
# 7007

# %%
data["DISCOUNT"].value_counts().mean()
# Out:
# np.float64(445.75757575757575)

# %%
data["DISCOUNT"].value_counts()
# Out:
# DISCOUNT
# 50% off    7557
# Nan        7007
# 30% off    2749
# 60% off    2634
# 40% off    2186
#            ...
# 22% off       1
# 66% off       1
# 77% off       1
# 28% off       1
# 36% off       1
# Name: count, Length: 66, dtype: int64

# %%
data["DISCOUNT"].value_counts().iloc[9:20]
# Out:
# DISCOUNT
# 45% off    523
# 10% off    497
# 25% off    340
# 35% off    304
# 5% off     254
# 75% off    202
# 15% off     84
# 80% off     71
# 67% off     48
# 69% off     43
# 41% off     32
# Name: count, dtype: int64

# %%
data["DISCOUNT"]=data["DISCOUNT"].str.replace("Nan","10% off")

# %%
data["DISCOUNT"][8]
# Out:
# '60% off'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29420 entries, 0 to 30757
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S_NO        29420 non-null  int64
#  1   BRAND_NAME  29420 non-null  object
#  2   DEATILS     29420 non-null  object
#  3   SIZES       29420 non-null  object
#  4   MRP         29420 non-null  int64
#  5   SELL_PRICE  29420 non-null  int64
#  6   DISCOUNT    29420 non-null  object
#  7   CATEGORY    29420 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 3.0+ MB

# %%
# now i am working in the column data["CATEGORY"]

# %%
data["CATEGORY"].value_counts()
# Out:
# CATEGORY
# Westernwear-Women           9961
# Indianwear-Women            9857
# Lingerie&Nightwear-Women    3221
# Footwear-Women              2465
# Watches-Women               1724
# Jewellery-Women             1717
# Fragrance-Women              475
# Name: count, dtype: int64

# %%
count=0
for i in data["CATEGORY"]:
    if(i=="Nan"):
        count=count+1
print(count)
# Out:
# 0

# %%
# finaly the row data clean the no of rows
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29420 entries, 0 to 30757
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S_NO        29420 non-null  int64
#  1   BRAND_NAME  29420 non-null  object
#  2   DEATILS     29420 non-null  object
#  3   SIZES       29420 non-null  object
#  4   MRP         29420 non-null  int64
#  5   SELL_PRICE  29420 non-null  int64
#  6   DISCOUNT    29420 non-null  object
#  7   CATEGORY    29420 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 3.0+ MB

# %%
 # the lost of no of row data aprox 6000 data

# %%
data.to_csv("FashionDataset_code_data_After cleaning.csv",index=False)
