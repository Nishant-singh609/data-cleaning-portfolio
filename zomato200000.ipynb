# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv("zomato_before_cleaning_data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
data.shape # the number of row and the number of the column
# Out:
# (51717, 17)

# %%
data.head(90)
# Out:
#                                                   url  \
# 0   https://www.zomato.com/bangalore/jalsa-banasha...
# 1   https://www.zomato.com/bangalore/spice-elephan...
# 2   https://www.zomato.com/SanchurroBangalore?cont...
# 3   https://www.zomato.com/bangalore/addhuri-udupi...
# 4   https://www.zomato.com/bangalore/grand-village...
# ..                                                ...
# 85  https://www.zomato.com/bangalore/the-big-o-bak...
# 86  https://www.zomato.com/bangalore/meghana-foods...
# 87  https://www.zomato.com/bangalore/krishna-sagar...
# 88  https://www.zomato.com/bangalore/dessert-rose-...
# 89  https://www.zomato.com/bangalore/chickpet-donn...
#
#                                               address  \
# 0   942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1   2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2   1112, Next to KIMS Medical College, 17th Cross...
# 3   1st Floor, Annakuteera, 3rd Stage, Banashankar...
# ...

# %%
data.tail(10)
# Out:
#                                                      url  \
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51709  https://www.zomato.com/bangalore/the-farm-hous...
# 51710  https://www.zomato.com/bangalore/topsy-turvey-...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51710  2E2, 4th Cross Road, Devasandra Industrial Est...
# ...

# %%
data.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
# the columns convert into (upper case ,lower case) so i cose the upper case
data1=[]
for i in data.columns:
    data1.append(i.upper())

# %%
copy1=data.copy()

# %%
copy1.columns=data1

# %%
copy1 # the columns convert into upper case  so
# Out:
#                                                      URL  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  ADDRESS  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
copy1.columns
# Out:
# Index(['URL', 'ADDRESS', 'NAME', 'ONLINE_ORDER', 'BOOK_TABLE', 'RATE', 'VOTES',
#        'PHONE', 'LOCATION', 'REST_TYPE', 'DISH_LIKED', 'CUISINES',
#        'APPROX_COST(FOR TWO PEOPLE)', 'REVIEWS_LIST', 'MENU_ITEM',
#        'LISTED_IN(TYPE)', 'LISTED_IN(CITY)'],
#       dtype='object')

# %%
copy1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   URL                          51717 non-null  object
#  1   ADDRESS                      51717 non-null  object
#  2   NAME                         51717 non-null  object
#  3   ONLINE_ORDER                 51717 non-null  object
#  4   BOOK_TABLE                   51717 non-null  object
#  5   RATE                         43942 non-null  object
#  6   VOTES                        51717 non-null  int64
#  7   PHONE                        50509 non-null  object
#  8   LOCATION                     51696 non-null  object
#  9   REST_TYPE                    51490 non-null  object
#  10  DISH_LIKED                   23639 non-null  object
#  11  CUISINES                     51672 non-null  object
#  12  APPROX_COST(FOR TWO PEOPLE)  51371 non-null  object
# ...

# %%
copy1.isnull().sum()
# Out:
# URL                                0
# ADDRESS                            0
# NAME                               0
# ONLINE_ORDER                       0
# BOOK_TABLE                         0
# RATE                            7775
# VOTES                              0
# PHONE                           1208
# LOCATION                          21
# REST_TYPE                        227
# DISH_LIKED                     28078
# CUISINES                          45
# APPROX_COST(FOR TWO PEOPLE)      346
# REVIEWS_LIST                       0
# MENU_ITEM                          0
# LISTED_IN(TYPE)                    0
# LISTED_IN(CITY)                    0
# dtype: int64

# %%
copy1["URL"].value_counts()
# Out:
# URL
# https://www.zomato.com/bangalore/the-nest-the-den-bengaluru-itpl-main-road-whitefield-bangalore?context=eyJzZSI6eyJlIjpbIjU4MzU0IiwiMTg3NDExMjkiLCIxODY2MTA0MCIsIjE4NjYxMDg0IiwxODY5MDgzN10sInQiOiJQdWJzICZhbXA7IEJhcnMgaW4gV2hpdGVmaWVsZCJ9fQ==                                                                                        1
# https://www.zomato.com/bangalore/jalsa-banashankari?context=eyJzZSI6eyJlIjpbNTg2OTQsIjE4Mzc1NDc0IiwiNTkwOTAiLCIxODM4Mjk0NCIsIjE4MjI0Njc2IiwiNTkyODkiLCIxODM3MzM4NiJdLCJ0IjoiUmVzdGF1cmFudHMgaW4gQmFuYXNoYW5rYXJpIHNlcnZpbmcgQnVmZmV0In19                                                                                                1
# ...

# %%
copy1["ADDRESS"].value_counts().iloc[128:150]
# Out:
# ADDRESS
# 2, Dickenson Road, FM Cariappa Colony, Sivanchetti Gardens, Commercial Street, Bangalore         19
# 307, Thimmaiah Rd, Govinda Chetty Colony, Shivajinagar, Bangalore                                19
# The Ambara, 22, Annaswami Mudaliar Road, Near Ulsoor Lake, Ulsoor, Bangalore                     19
# 14, Patel Medicals, 7th Main, BTM 2nd Stage, BTM, Bangalore                                      19
# 42, 1st Main, Koramangala 1st Block, Bangalore                                                   19
# 1086/A, Twin Tulips, 18th Cross, 14th Main Road, Sector 3, HSR, Bangalore                        19
# 28, Ground Floor, SG Palaya, Behind Chirst College, BTM, Bangalore                               18
# 122/B, Jyothi Nivas Road, 5th Block, Koramangala 5th Block, Bangalore                            18
# Money Chambers Double Road, Shanti Nagar, Bangalore                                              18
# ...

# %%
copy1.columns
# Out:
# Index(['URL', 'ADDRESS', 'NAME', 'ONLINE_ORDER', 'BOOK_TABLE', 'RATE', 'VOTES',
#        'PHONE', 'LOCATION', 'REST_TYPE', 'DISH_LIKED', 'CUISINES',
#        'APPROX_COST(FOR TWO PEOPLE)', 'REVIEWS_LIST', 'MENU_ITEM',
#        'LISTED_IN(TYPE)', 'LISTED_IN(CITY)'],
#       dtype='object')

# %%
# to the ccolumn devided into the two part no of row form 
columns_keep=['NAME','ONLINE_ORDER','BOOK_TABLE','RATE','DISH_LIKED','APPROX_COST(FOR TWO PEOPLE)']
columns_drops=['URL','ADDRESS','VOTES','PHONE', 'LOCATION', 'REST_TYPE','CUISINES', 'REVIEWS_LIST', 'MENU_ITEM','LISTED_IN(TYPE)', 'LISTED_IN(CITY)']

# %%
copy1.isnull().sum()
# Out:
# URL                                0
# ADDRESS                            0
# NAME                               0
# ONLINE_ORDER                       0
# BOOK_TABLE                         0
# RATE                            7775
# VOTES                              0
# PHONE                           1208
# LOCATION                          21
# REST_TYPE                        227
# DISH_LIKED                     28078
# CUISINES                          45
# APPROX_COST(FOR TWO PEOPLE)      346
# REVIEWS_LIST                       0
# MENU_ITEM                          0
# LISTED_IN(TYPE)                    0
# LISTED_IN(CITY)                    0
# dtype: int64

# %%
print(keep_col.shape)
print()
keep_col.isnull().sum()
# Out:
# (51717, 6)
# NAME                               0
# ONLINE_ORDER                       0
# BOOK_TABLE                         0
# RATE                            7775
# DISH_LIKED                     28078
# APPROX_COST(FOR TWO PEOPLE)      346
# dtype: int64

# %% [markdown]
# # to take the columns in the 6 that columns are import  to me

# %%
new_take_columns=copy1[columns_keep]

# %%
len(new_take_columns) # to take the columns in the 6 that columns are import  to me 
new_take_columns.shape
# Out:
# (51717, 6)

# %% [markdown]
#  # to drop the columns in the 11 that columns are not important  to me

# %%
columns_drops1=copy1[columns_drops]  # to drop the columns in the 11 that columns are not important  to me 
columns_drops1.shape
# Out:
# (51717, 11)

# %% [markdown]
#  # now i am woring in the  new_take_columns=copy1[columns_keep] fillter

# %%
new_take_columns.duplicated().sum()
# Out:
# np.int64(32808)

# %%
new_take_columns.duplicated().value_counts()
# Out:
# True     32808
# False    18909
# Name: count, dtype: int64

# %%
new_take_columns.duplicated().iloc[0:50000].value_counts()
# Out:
# True     31900
# False    18100
# Name: count, dtype: int64

# %% [markdown]
# new_take=copy1[columns_keep]

# %%
# delete the dublicate data  so
# to dubilicate

# %%
new_take_columns.drop_duplicates(inplace=True)
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_66942/2851206104.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_take_columns.drop_duplicates(inplace=True)

# %%
new_take_columns.duplicated().sum()
# Out:
# np.int64(0)

# %%
new_take_columns.isnull().sum()
# Out:
# NAME                               0
# ONLINE_ORDER                       0
# BOOK_TABLE                         0
# RATE                            2418
# DISH_LIKED                     10587
# APPROX_COST(FOR TWO PEOPLE)      140
# dtype: int64

# %%
new_take_columns["RATE"].isnull().sum()
# Out:
# np.int64(2418)

# %%
new_take_columns.dropna(subset=["RATE"],inplace=True)
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_66942/3383835617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_take_columns.dropna(subset=["RATE"],inplace=True)

# %%
new_take_columns.isnull().sum()
# Out:
# NAME                              0
# ONLINE_ORDER                      0
# BOOK_TABLE                        0
# RATE                              0
# DISH_LIKED                     8199
# APPROX_COST(FOR TWO PEOPLE)      99
# dtype: int64

# %%
# now i am working i the columns DISH_LIKED

# %%
new_take_columns.head(9)
# Out:
#                                               NAME ONLINE_ORDER BOOK_TABLE  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# 5                                  Timepass Dinner          Yes         No
# 6  Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                           Onesta          Yes        Yes
# 8                                   Penthouse Cafe          Yes         No
#
#     RATE                                         DISH_LIKED  \
# 0  4.1/5  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  4.1/5  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# ...

# %%
new_take_columns["DISH_LIKED"].value_counts()
# Out:
# DISH_LIKED
# Biryani                                                                            78
# Chicken Biryani                                                                    32
# Paratha                                                                            28
# Friendly Staff                                                                     26
# Pizza                                                                              22
#                                                                                    ..
# Coffee, Spaghetti, Pancakes, Nachos, Pasta, Sandwich, Garlic Bread                  1
# Mocktails, Peri Fries, Lasagne, Pizza, Chicken Bbq Wings, Virgin Mojito, Nachos     1
# Waffles, Pasta, Crispy Chicken, Honey Chilli Chicken, Sandwich, Coffee, Crepe       1
# Waffles, Pasta, Coleslaw Sandwich, Choco Waffle, Tacos, Momos, Cheese Nachos        1
# Pizza, Mocktails, Coffee, Nachos, Salad, Pasta, Sandwiches                          1
# ...

# %%
new_take_columns["DISH_LIKED"]=new_take_columns["DISH_LIKED"].fillna(method="ffill")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_66942/2009411451.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_take_columns["DISH_LIKED"]=new_take_columns["DISH_LIKED"].fillna(method="ffill")
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_66942/2009411451.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_take_columns["DISH_LIKED"]=new_take_columns["DISH_LIKED"].fillna(method="ffill")

# %%
new_take_columns["DISH_LIKED"].value_counts().sum()
# Out:
# np.int64(16491)

# %%
new_take_columns["DISH_LIKED"].isnull().sum()
# Out:
# np.int64(0)

# %%
new_take_columns.isnull().sum()
# Out:
# NAME                            0
# ONLINE_ORDER                    0
# BOOK_TABLE                      0
# RATE                            0
# DISH_LIKED                      0
# APPROX_COST(FOR TWO PEOPLE)    99
# dtype: int64

# %%
new_take_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16491 entries, 0 to 51677
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   NAME                         16491 non-null  object
#  1   ONLINE_ORDER                 16491 non-null  object
#  2   BOOK_TABLE                   16491 non-null  object
#  3   RATE                         16491 non-null  object
#  4   DISH_LIKED                   16491 non-null  object
#  5   APPROX_COST(FOR TWO PEOPLE)  16392 non-null  object
# dtypes: object(6)
# memory usage: 901.9+ KB

# %%
# now i am working in the  APPROX_COST(FOR TWO PEOPLE)

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].value_counts()
# Out:
# APPROX_COST(FOR TWO PEOPLE)
# 400      2293
# 300      2287
# 500      1681
# 200      1492
# 600      1222
#          ...
# 4,100       1
# 5,000       1
# 120         1
# 3,700       1
# 4,500       1
# Name: count, Length: 66, dtype: int64

# %%
type(new_take_columns["APPROX_COST(FOR TWO PEOPLE)"][9])
# Out:
# str

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].iloc[200:400]
# Out:
# 235      450
# 236      450
# 237      150
# 238      250
# 240      250
#        ...
# 455      200
# 457    1,000
# 459      150
# 461      750
# 462      200
# Name: APPROX_COST(FOR TWO PEOPLE), Length: 200, dtype: object

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"][80:91]
# Out:
# 82    200
# 83    700
# 85    300
# 86    600
# 87    200
# 88    500
# 89    250
# 93    300
# 94    600
# 95    800
# 96    250
# Name: APPROX_COST(FOR TWO PEOPLE), dtype: object

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"]=new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].str.replace(",","")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_66942/3114813140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_take_columns["APPROX_COST(FOR TWO PEOPLE)"]=new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].str.replace(",","")

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].iloc[200:400]
# Out:
# 235     450
# 236     450
# 237     150
# 238     250
# 240     250
#        ...
# 455     200
# 457    1000
# 459     150
# 461     750
# 462     200
# Name: APPROX_COST(FOR TWO PEOPLE), Length: 200, dtype: object

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"]=new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].str.replace(" ","")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_66942/637926967.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_take_columns["APPROX_COST(FOR TWO PEOPLE)"]=new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].str.replace(" ","")

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].iloc[200:400]
# Out:
# 235     450
# 236     450
# 237     150
# 238     250
# 240     250
#        ...
# 455     200
# 457    1000
# 459     150
# 461     750
# 462     200
# Name: APPROX_COST(FOR TWO PEOPLE), Length: 200, dtype: object

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].isnull().sum()
# Out:
# np.int64(99)

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"]=new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].astype(float)
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_66942/393801972.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_take_columns["APPROX_COST(FOR TWO PEOPLE)"]=new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].astype(float)

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"]=new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].fillna(new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].mean())
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_66942/915243572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_take_columns["APPROX_COST(FOR TWO PEOPLE)"]=new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].fillna(new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].mean())

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].isnull().sum()
# Out:
# np.int64(0)

# %%
new_take_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16491 entries, 0 to 51677
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   NAME                         16491 non-null  object
#  1   ONLINE_ORDER                 16491 non-null  object
#  2   BOOK_TABLE                   16491 non-null  object
#  3   RATE                         16491 non-null  object
#  4   DISH_LIKED                   16491 non-null  object
#  5   APPROX_COST(FOR TWO PEOPLE)  16491 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 1.4+ MB

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"]=new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].astype(str)
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_66942/2005137197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_take_columns["APPROX_COST(FOR TWO PEOPLE)"]=new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].astype(str)

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"]=new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[197], line 1
# ----> 1 new_take_columns["APPROX_COST(FOR TWO PEOPLE)"]=new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].astype(int)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"] = new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].astype(float)
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_66942/4165747126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_take_columns["APPROX_COST(FOR TWO PEOPLE)"] = new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].astype(float)

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"] = new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].astype(int)
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_66942/1597607029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_take_columns["APPROX_COST(FOR TWO PEOPLE)"] = new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].astype(int)

# %%
new_take_columns["APPROX_COST(FOR TWO PEOPLE)"].value_counts()
# Out:
# APPROX_COST(FOR TWO PEOPLE)
# 400     2293
# 300     2287
# 500     1681
# 200     1492
# 600     1222
#         ...
# 4100       1
# 5000       1
# 120        1
# 3700       1
# 4500       1
# Name: count, Length: 67, dtype: int64

# %%
new_take_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16491 entries, 0 to 51677
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   NAME                         16491 non-null  object
#  1   ONLINE_ORDER                 16491 non-null  object
#  2   BOOK_TABLE                   16491 non-null  object
#  3   RATE                         16491 non-null  object
#  4   DISH_LIKED                   16491 non-null  object
#  5   APPROX_COST(FOR TWO PEOPLE)  16491 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 1.4+ MB

# %%
new_take_columns
# Out:
#                                               NAME ONLINE_ORDER BOOK_TABLE  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# ...                                            ...          ...        ...
# 51628  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 51631                                Just Parathas           No         No
# 51632                             SeeYa Restaurant           No         No
# 51641                                Andhra Spices           No         No
# 51677                                      Bhagini           No         No
#
#          RATE                                         DISH_LIKED  \
# ...

# %%
new_take_columns.isnull().sum()
# Out:
# NAME                           0
# ONLINE_ORDER                   0
# BOOK_TABLE                     0
# RATE                           0
# DISH_LIKED                     0
# APPROX_COST(FOR TWO PEOPLE)    0
# dtype: int64

# %%
new_take_columns.to_csv("Zomato_after_cleanind_data.csv")
