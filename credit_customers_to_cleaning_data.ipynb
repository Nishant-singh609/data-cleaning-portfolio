# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("credit_customers.csv")

# %%
data.head(20)
# Out:
#    checking_status  duration                  credit_history  \
# 0               <0       6.0  critical/other existing credit
# 1         0<=X<200      48.0                   existing paid
# 2      no checking      12.0  critical/other existing credit
# 3               <0      42.0                   existing paid
# 4               <0      24.0              delayed previously
# 5      no checking      36.0                   existing paid
# 6      no checking      24.0                   existing paid
# 7         0<=X<200      36.0                   existing paid
# 8      no checking      12.0                   existing paid
# 9         0<=X<200      30.0  critical/other existing credit
# 10        0<=X<200      12.0                   existing paid
# 11              <0      48.0                   existing paid
# 12        0<=X<200      12.0                   existing paid
# 13              <0      24.0  critical/other existing credit
# ...

# %%
data.head(2)
# Out:
#   checking_status  duration                  credit_history   purpose  \
# 0              <0       6.0  critical/other existing credit  radio/tv
# 1        0<=X<200      48.0                   existing paid  radio/tv
#
#    credit_amount    savings_status employment  installment_commitment  \
# 0         1169.0  no known savings        >=7                     4.0
# 1         5951.0              <100     1<=X<4                     2.0
#
#       personal_status other_parties  ...  property_magnitude   age  \
# 0         male single          none  ...         real estate  67.0
# 1  female div/dep/mar          none  ...         real estate  22.0
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own              2.0  skilled            1.0
# 1                 none     own              1.0  skilled            1.0
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
# ...

# %%
data.tail(7)
# Out:
#     checking_status  duration                  credit_history  \
# 993              <0      36.0                   existing paid
# 994     no checking      12.0                   existing paid
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 993  furniture/equipment         3959.0              <100  unemployed
# 994              new car         2390.0  no known savings         >=7
# 995  furniture/equipment         1736.0              <100      4<=X<7
# 996             used car         3857.0              <100      1<=X<4
# 997             radio/tv          804.0              <100         >=7
# ...

# %%
data.shape
# Out:
# (1000, 21)

# %%
data.columns # first the columns convert in to the caplitalized form
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
data_columns=[]
for i in data.columns:
    data_columns.append(i.capitalize())

# %%
data_columns
# Out:
# ['Checking_status',
#  'Duration',
#  'Credit_history',
#  'Purpose',
#  'Credit_amount',
#  'Savings_status',
#  'Employment',
#  'Installment_commitment',
#  'Personal_status',
#  'Other_parties',
#  'Residence_since',
#  'Property_magnitude',
#  'Age',
#  'Other_payment_plans',
#  'Housing',
#  'Existing_credits',
#  'Job',
#  'Num_dependents',
#  'Own_telephone',
#  'Foreign_worker',
#  'Class']

# %%
 data1=data.copy()

# %%
data1.columns=data_columns

# %%
data1.duplicated().sum() # its not present in the duplicated values in the data set
# Out:
# np.int64(0)

# %%
#to take the info
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Checking_status         1000 non-null   object
#  1   Duration                1000 non-null   float64
#  2   Credit_history          1000 non-null   object
#  3   Purpose                 1000 non-null   object
#  4   Credit_amount           1000 non-null   float64
#  5   Savings_status          1000 non-null   object
#  6   Employment              1000 non-null   object
#  7   Installment_commitment  1000 non-null   float64
#  8   Personal_status         1000 non-null   object
#  9   Other_parties           1000 non-null   object
#  10  Residence_since         1000 non-null   float64
#  11  Property_magnitude      1000 non-null   object
#  12  Age                     1000 non-null   float64
#  13  Other_payment_plans     1000 non-null   object
# ...

# %%
# i toke the usable columns in the data set the other columns are deletete with in secounds
data1.columns
# Out:
# Index(['Checking_status', 'Duration', 'Credit_history', 'Purpose',
#        'Credit_amount', 'Savings_status', 'Employment',
#        'Installment_commitment', 'Personal_status', 'Other_parties',
#        'Residence_since', 'Property_magnitude', 'Age', 'Other_payment_plans',
#        'Housing', 'Existing_credits', 'Job', 'Num_dependents', 'Own_telephone',
#        'Foreign_worker', 'Class'],
#       dtype='object')

# %%
data1.drop(columns=['Checking_status', 'Duration', 'Credit_history', 'Purpose','Employment',
       'Installment_commitment','Other_parties','Residence_since', 'Other_payment_plans','Num_dependents'],inplace=True)

# %%
data1.columns
# Out:
# Index(['Credit_amount', 'Savings_status', 'Personal_status',
#        'Property_magnitude', 'Age', 'Housing', 'Existing_credits', 'Job',
#        'Own_telephone', 'Foreign_worker', 'Class'],
#       dtype='object')

# %%
data1.head(5) # Savings_status that columns also delete the data set
# Out:
#    Credit_amount    Savings_status     Personal_status Property_magnitude  \
# 0         1169.0  no known savings         male single        real estate
# 1         5951.0              <100  female div/dep/mar        real estate
# 2         2096.0              <100         male single        real estate
# 3         7882.0              <100         male single     life insurance
# 4         4870.0              <100         male single  no known property
#
#     Age   Housing  Existing_credits                 Job Own_telephone  \
# 0  67.0       own               2.0             skilled           yes
# 1  22.0       own               1.0             skilled          none
# 2  49.0       own               1.0  unskilled resident          none
# 3  45.0  for free               1.0             skilled          none
# 4  53.0  for free               2.0             skilled          none
#
#   Foreign_worker Class
# 0            yes  good
# 1            yes   bad
# 2            yes  good
# ...

# %%
data1.drop(columns=["Savings_status"],inplace=True)

# %%
data1.columns
# Out:
# Index(['Credit_amount', 'Personal_status', 'Property_magnitude', 'Age',
#        'Housing', 'Existing_credits', 'Job', 'Own_telephone', 'Foreign_worker',
#        'Class'],
#       dtype='object')

# %%
data1
# Out:
#      Credit_amount     Personal_status Property_magnitude   Age   Housing  \
# 0           1169.0         male single        real estate  67.0       own
# 1           5951.0  female div/dep/mar        real estate  22.0       own
# 2           2096.0         male single        real estate  49.0       own
# 3           7882.0         male single     life insurance  45.0  for free
# 4           4870.0         male single  no known property  53.0  for free
# ..             ...                 ...                ...   ...       ...
# 995         1736.0  female div/dep/mar        real estate  31.0       own
# 996         3857.0        male div/sep     life insurance  40.0       own
# 997          804.0         male single                car  38.0       own
# 998         1845.0         male single  no known property  23.0  for free
# 999         4576.0         male single                car  27.0       own
#
#      Existing_credits                        Job Own_telephone Foreign_worker  \
# ...

# %%
data1["Credit_amount"].value_counts()
# Out:
# Credit_amount
# 1275.0    3
# 1262.0    3
# 1478.0    3
# 1393.0    3
# 1258.0    3
#          ..
# 454.0     1
# 1715.0    1
# 2520.0    1
# 3568.0    1
# 7166.0    1
# Name: count, Length: 921, dtype: int64

# %%
# the we can cheak the duplicated value in the data1 set
data1.duplicated().sum() # in the darta set not present in the data set
# Out:
# np.int64(0)

# %%
data1.isnull().sum()
# Out:
# Credit_amount         0
# Personal_status       0
# Property_magnitude    0
# Age                   0
# Housing               0
# Existing_credits      0
# Job                   0
# Own_telephone         0
# Foreign_worker        0
# Class                 0
# dtype: int64

# %%
 # cheak the each and every columns  so to cheak the each columns
data1["Credit_amount"].value_counts()
# Out:
# Credit_amount
# 1275.0    3
# 1262.0    3
# 1478.0    3
# 1393.0    3
# 1258.0    3
#          ..
# 454.0     1
# 1715.0    1
# 2520.0    1
# 3568.0    1
# 7166.0    1
# Name: count, Length: 921, dtype: int64

# %%
data1["Personal_status"].value_counts()
# Out:
# Personal_status
# male single           548
# female div/dep/mar    310
# male mar/wid           92
# male div/sep           50
# Name: count, dtype: int64

# %%
data1["Property_magnitude"].value_counts()
# Out:
# Property_magnitude
# car                  332
# real estate          282
# life insurance       232
# no known property    154
# Name: count, dtype: int64

# %%
data1["Age"].value_counts()
# Out:
# Age
# 27.0    51
# 26.0    50
# 23.0    48
# 24.0    44
# 28.0    43
# 25.0    41
# 30.0    40
# 35.0    40
# 36.0    39
# 31.0    38
# 29.0    37
# 32.0    34
# 33.0    33
# 34.0    32
# 37.0    29
# 22.0    27
# 40.0    25
# 38.0    24
# 42.0    22
# 39.0    21
# 46.0    18
# 44.0    17
# 41.0    17
# 43.0    17
# 47.0    17
# 45.0    15
# 21.0    14
# 49.0    14
# 20.0    14
# 50.0    12
# 48.0    12
# 54.0    10
# 57.0     9
# 52.0     9
# 63.0     8
# 51.0     8
# 55.0     8
# 53.0     7
# 61.0     7
# 60.0     6
# 66.0     5
# 65.0     5
# 58.0     5
# 64.0     5
# 74.0     4
# 67.0     3
# 56.0     3
# 59.0     3
# 68.0     3
# 19.0     2
# 75.0     2
# 62.0     2
# 70.0     1
# Name: count, dtype: int64

# %%
data1["Housing"].value_counts()
# Out:
# Housing
# own         713
# rent        179
# for free    108
# Name: count, dtype: int64

# %%
data1["Existing_credits"].value_counts()
# Out:
# Existing_credits
# 1.0    633
# 2.0    333
# 3.0     28
# 4.0      6
# Name: count, dtype: int64

# %%
data1["Existing_credits"][8]
# Out:
# np.float64(1.0)

# %%
data1["Existing_credits"]=data1["Existing_credits"].astype(int)

# %%
data1["Existing_credits"][8]
# Out:
# np.int64(1)

# %%
data1["Own_telephone"].value_counts()
# Out:
# Own_telephone
# none    596
# yes     404
# Name: count, dtype: int64

# %%
data1["Foreign_worker"].value_counts()
# Out:
# Foreign_worker
# yes    963
# no      37
# Name: count, dtype: int64

# %%
data1["Foreign_worker"].unique() # convert into zero and one
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data1["Foreign_worker"]=data1["Foreign_worker"].apply(lambda x:1 if x=="yes" else 0)

# %%
data1
# Out:
#      Credit_amount     Personal_status Property_magnitude   Age   Housing  \
# 0           1169.0         male single        real estate  67.0       own
# 1           5951.0  female div/dep/mar        real estate  22.0       own
# 2           2096.0         male single        real estate  49.0       own
# 3           7882.0         male single     life insurance  45.0  for free
# 4           4870.0         male single  no known property  53.0  for free
# ..             ...                 ...                ...   ...       ...
# 995         1736.0  female div/dep/mar        real estate  31.0       own
# 996         3857.0        male div/sep     life insurance  40.0       own
# 997          804.0         male single                car  38.0       own
# 998         1845.0         male single  no known property  23.0  for free
# 999         4576.0         male single                car  27.0       own
#
#      Existing_credits                        Job Own_telephone  \
# ...

# %%
data1["Class"].value_counts()
# Out:
# Class
# good    700
# bad     300
# Name: count, dtype: int64

# %%
data1["Class"].unique() # so onvert into the zero and one
# Out:
# array(['good', 'bad'], dtype=object)

# %%
data1["Class"]=data1["Class"].apply(lambda x:1 if x=="good" else 0)

# %%
data1
# Out:
#      Credit_amount     Personal_status Property_magnitude   Age   Housing  \
# 0           1169.0         male single        real estate  67.0       own
# 1           5951.0  female div/dep/mar        real estate  22.0       own
# 2           2096.0         male single        real estate  49.0       own
# 3           7882.0         male single     life insurance  45.0  for free
# 4           4870.0         male single  no known property  53.0  for free
# ..             ...                 ...                ...   ...       ...
# 995         1736.0  female div/dep/mar        real estate  31.0       own
# 996         3857.0        male div/sep     life insurance  40.0       own
# 997          804.0         male single                car  38.0       own
# 998         1845.0         male single  no known property  23.0  for free
# 999         4576.0         male single                car  27.0       own
#
#      Existing_credits                        Job Own_telephone Foreign_worker  \
# ...

# %%
data1.to_csv("before cleaning_credit_customers.csv",index=False)
