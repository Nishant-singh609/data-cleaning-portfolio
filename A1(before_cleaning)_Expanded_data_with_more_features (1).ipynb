# %%
import numpy as np
import pandas as pd
import matplotlib as plt
data=pd.read_csv("A1(before_cleaning)_Expanded_data_with_more_features (1).csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %%
data.tail()
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 30636       none              single     sometimes           no         2.0
# 30637       none              single     regularly           no         1.0
# 30638  completed             married     sometimes           no         1.0
# 30639  completed             married     regularly           no         3.0
# 30640       none             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# ...

# %%
 # first columns name is the removed data["	Unnamed: 0"]

# %%
data.drop(columns="Unnamed: 0",inplace=True)

# %%
data.columns 
data.shape
# Out:
# (30641, 14)

# %%
data.isnull().sum()
# Out:
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
data.duplicated().sum() # no duplicate value present in the null value in the columns
# Out:
# np.int64(0)

# %%
data.columns  # the columns name convert into the the lower case
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
new_columns=[]
for i in data.columns:
    new_columns.append(i.lower())
new_columns
# Out:
# ['gender',
#  'ethnicgroup',
#  'parenteduc',
#  'lunchtype',
#  'testprep',
#  'parentmaritalstatus',
#  'practicesport',
#  'isfirstchild',
#  'nrsiblings',
#  'transportmeans',
#  'wklystudyhours',
#  'mathscore',
#  'readingscore',
#  'writingscore']

# %%
data1=data.copy()

# %%
data1.column=new_columns
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_13327/2717124350.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data1.column=new_columns

# %%
data1.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
data1.rename(columns={"EthnicGroup":"Ethnic_Group"},inplace=True)

# %%
data1.rename(columns={'ParentEduc':'Parent_Educ', 'LunchType':'Lunch_Type', 'TestPrep':'Test_Prep',
       'ParentMaritalStatus':'Parent_Marital_Status', 'PracticeSport':'Practice_Sport', 'IsFirstChild':'Is_First_Child', 'NrSiblings':'Nr_Siblings',
       'TransportMeans':'Transport_Means', 'WklyStudyHours':'Wkly_Study_Hours', 'MathScore':'Math_Score', 'ReadingScore':'Reading_Score',
       'WritingScore':'Writing_Score'},inplace=True)

# %%
data.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               30641 non-null  object
#  1   EthnicGroup          28801 non-null  object
#  2   ParentEduc           28796 non-null  object
#  3   LunchType            30641 non-null  object
#  4   TestPrep             28811 non-null  object
#  5   ParentMaritalStatus  29451 non-null  object
#  6   PracticeSport        30010 non-null  object
#  7   IsFirstChild         29737 non-null  object
#  8   NrSiblings           29069 non-null  float64
#  9   TransportMeans       27507 non-null  object
#  10  WklyStudyHours       29686 non-null  object
#  11  MathScore            30641 non-null  int64
#  12  ReadingScore         30641 non-null  int64
#  13  WritingScore         30641 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 3.3+ MB

# %%
data1.isnull().sum()
# Out:
# Gender                      0
# Ethnic_Group             1840
# Parent_Educ              1845
# Lunch_Type                  0
# Test_Prep                1830
# Parent_Marital_Status    1190
# Practice_Sport            631
# Is_First_Child            904
# Nr_Siblings              1572
# Transport_Means          3134
# Wkly_Study_Hours          955
# Math_Score                  0
# Reading_Score               0
# Writing_Score               0
# dtype: int64

# %%
# know i am working in the columns data1["Ethnic_Group"]

# %%
data1["Ethnic_Group"].value_counts()
# Out:
# Ethnic_Group
# group C    9212
# group D    7503
# group B    5826
# group E    4041
# group A    2219
# Name: count, dtype: int64

# %%
data1["Ethnic_Group"].isnull().sum()
# Out:
# np.int64(1840)

# %%
data1["Ethnic_Group"].isnull().sum()
# Out:
# np.int64(1840)

# %%
data1["Ethnic_Group"].value_counts()
# Out:
# Ethnic_Group
# group C    9212
# group D    7503
# group B    5826
# group E    4041
# group A    2219
# Name: count, dtype: int64

# %%
print(data1["Ethnic_Group"].value_counts().mode())
print("mean")
print(data1["Ethnic_Group"].value_counts().mean())
# Out:
# 0    2219
# 1    4041
# 2    5826
# 3    7503
# 4    9212
# Name: count, dtype: int64
# mean
# 5760.2

# %%
#data1["Ethnic_Group"]=data1["Ethnic_Group"].fillna(data1["Ethnic_Group"].mean()[0])

data1["Ethnic_Group"] = data1["Ethnic_Group"].fillna(data1["Ethnic_Group"].mode()[0])

# %%
data1["Ethnic_Group"].value_counts()
# Out:
# Ethnic_Group
# group C    11052
# group D     7503
# group B     5826
# group E     4041
# group A     2219
# Name: count, dtype: int64

# %%
data1.isnull().sum()
# Out:
# Gender                      0
# Ethnic_Group                0
# Parent_Educ              1845
# Lunch_Type                  0
# Test_Prep                1830
# Parent_Marital_Status    1190
# Practice_Sport            631
# Is_First_Child            904
# Nr_Siblings              1572
# Transport_Means          3134
# Wkly_Study_Hours          955
# Math_Score                  0
# Reading_Score               0
# Writing_Score               0
# dtype: int64

# %%
# now  i am working in the columns data1["Parent_Educ"]

# %%
data1["Parent_Educ"].value_counts()
# Out:
# Parent_Educ
# some college          6633
# high school           5687
# associate's degree    5550
# some high school      5517
# bachelor's degree     3386
# master's degree       2023
# Name: count, dtype: int64

# %%
data1["Parent_Educ"].value_counts().mean()
# Out:
# np.float64(4799.333333333333)

# %%
data1["Parent_Educ"]=data1["Ethnic_Group"].fillna(data1["Ethnic_Group"].mode()[0])

# %%
data1["Parent_Educ"].isnull().sum()
# Out:
# np.int64(0)

# %%
data1["Parent_Educ"].value_counts()
# Out:
# Parent_Educ
# group C    11052
# group D     7503
# group B     5826
# group E     4041
# group A     2219
# Name: count, dtype: int64

# %%
data1.isnull().sum()
# Out:
# Gender                      0
# Ethnic_Group                0
# Parent_Educ                 0
# Lunch_Type                  0
# Test_Prep                1830
# Parent_Marital_Status    1190
# Practice_Sport            631
# Is_First_Child            904
# Nr_Siblings              1572
# Transport_Means          3134
# Wkly_Study_Hours          955
# Math_Score                  0
# Reading_Score               0
# Writing_Score               0
# dtype: int64

# %%
# know i am working in the columns data1["Test_Prep"]

# %%
data1["Test_Prep"].isnull().sum()
# Out:
# np.int64(1830)

# %%
data1["Test_Prep"].value_counts()
# Out:
# Test_Prep
# none         18856
# completed     9955
# Name: count, dtype: int64

# %%
data1["Test_Prep"].value_counts().mean()
# Out:
# np.float64(14405.5)

# %%
data1["Test_Prep"]=data1["Test_Prep"].fillna(data1["Test_Prep"].mode()[0])

# %%
data1["Test_Prep"].value_counts()
# Out:
# Test_Prep
# none         20686
# completed     9955
# Name: count, dtype: int64

# %%
# # know i am working in the columns data1["Parent_Marital_Status"]

# %%
data1["Parent_Marital_Status"].value_counts()
# Out:
# Parent_Marital_Status
# married     16844
# single       7097
# divorced     4919
# widowed       591
# Name: count, dtype: int64

# %%
data1["Parent_Marital_Status"].value_counts().mode()
# Out:
# 0      591
# 1     4919
# 2     7097
# 3    16844
# Name: count, dtype: int64

# %%
data1["Parent_Marital_Status"].value_counts().mean()
# Out:
# np.float64(7362.75)

# %%
data1["Parent_Marital_Status"]=data1["Parent_Marital_Status"].fillna(data1["Parent_Marital_Status"].mode()[0])

# %%
data1.isnull().sum()
# Out:
# Gender                      0
# Ethnic_Group                0
# Parent_Educ                 0
# Lunch_Type                  0
# Test_Prep                   0
# Parent_Marital_Status       0
# Practice_Sport            631
# Is_First_Child            904
# Nr_Siblings              1572
# Transport_Means          3134
# Wkly_Study_Hours          955
# Math_Score                  0
# Reading_Score               0
# Writing_Score               0
# dtype: int64

# %%
# # know i am working in the columns data1["Practice_Sport"]

# %%
data1["Practice_Sport"].value_counts()
# Out:
# Practice_Sport
# sometimes    15213
# regularly    10793
# never         4004
# Name: count, dtype: int64

# %%
print(data1["Practice_Sport"].value_counts().mean())
data1["Practice_Sport"].value_counts().mode()
# Out:
# 10003.333333333334
# 0     4004
# 1    10793
# 2    15213
# Name: count, dtype: int64

# %%
data1["Practice_Sport"]=data1["Practice_Sport"].fillna(data1["Practice_Sport"].mode()[0])

# %%
data1.isnull().sum()
# Out:
# Gender                      0
# Ethnic_Group                0
# Parent_Educ                 0
# Lunch_Type                  0
# Test_Prep                   0
# Parent_Marital_Status       0
# Practice_Sport              0
# Is_First_Child            904
# Nr_Siblings              1572
# Transport_Means          3134
# Wkly_Study_Hours          955
# Math_Score                  0
# Reading_Score               0
# Writing_Score               0
# dtype: int64

# %%
# # know i am working in the columns data1["Is_First_Child"]
data1["Is_First_Child"].value_counts()
# Out:
# Is_First_Child
# yes    19082
# no     10655
# Name: count, dtype: int64

# %%
data1["Is_First_Child"].value_counts().mean()
# Out:
# np.float64(14868.5)

# %%
data1["Is_First_Child"].value_counts().mode()
# Out:
# 0    10655
# 1    19082
# Name: count, dtype: int64

# %%
data1["Is_First_Child"]=data1["Is_First_Child"].fillna(data1["Is_First_Child"].mode()[0])

# %%
data1.isnull().sum()
# Out:
# Gender                      0
# Ethnic_Group                0
# Parent_Educ                 0
# Lunch_Type                  0
# Test_Prep                   0
# Parent_Marital_Status       0
# Practice_Sport              0
# Is_First_Child              0
# Nr_Siblings              1572
# Transport_Means          3134
# Wkly_Study_Hours          955
# Math_Score                  0
# Reading_Score               0
# Writing_Score               0
# dtype: int64

# %%
# # know i am working in the columns data1["Nr_Siblings"]

# %%
data1["Nr_Siblings"].value_counts()
# Out:
# Nr_Siblings
# 1.0    8217
# 2.0    6790
# 3.0    6123
# 0.0    3085
# 4.0    2941
# 5.0    1320
# 6.0     302
# 7.0     291
# Name: count, dtype: int64

# %%
data1["Nr_Siblings"].value_counts().mean()
# Out:
# np.float64(3633.625)

# %%
data1["Nr_Siblings"].value_counts().mode()
# Out:
# 0     291
# 1     302
# 2    1320
# 3    2941
# 4    3085
# 5    6123
# 6    6790
# 7    8217
# Name: count, dtype: int64

# %%
data1["Nr_Siblings"].isnull().sum()
# Out:
# np.int64(1572)

# %%
data1["Nr_Siblings"]=data1["Nr_Siblings"].fillna(data1["Nr_Siblings"].mean())

# %%
data1["Nr_Siblings"].value_counts()
# Out:
# Nr_Siblings
# 1.000000    8217
# 2.000000    6790
# 3.000000    6123
# 0.000000    3085
# 4.000000    2941
# 2.145894    1572
# 5.000000    1320
# 6.000000     302
# 7.000000     291
# Name: count, dtype: int64

# %%
data1["Nr_Siblings"].isnull().sum()
# Out:
# np.int64(0)

# %%
# convert the data type
type(data1["Nr_Siblings"][7])
# Out:
# numpy.float64

# %%
 #to covert into the int type So in the

# %%
data1["Nr_Siblings"]=data1["Nr_Siblings"].astype(int)

# %%
data1["Nr_Siblings"].value_counts()
# Out:
# Nr_Siblings
# 2    8362
# 1    8217
# 3    6123
# 0    3085
# 4    2941
# 5    1320
# 6     302
# 7     291
# Name: count, dtype: int64

# %%
# convert the data type
type(data1["Nr_Siblings"][7])
# Out:
# numpy.int64

# %%
data1.isnull().sum()
# Out:
# Gender                      0
# Ethnic_Group                0
# Parent_Educ                 0
# Lunch_Type                  0
# Test_Prep                   0
# Parent_Marital_Status       0
# Practice_Sport              0
# Is_First_Child              0
# Nr_Siblings                 0
# Transport_Means          3134
# Wkly_Study_Hours          955
# Math_Score                  0
# Reading_Score               0
# Writing_Score               0
# dtype: int64

# %%
# # know i am working in the columns data1["Transport_Means"]

# %%
data1["Transport_Means"].isnull().sum()
# Out:
# np.int64(3134)

# %%
data1["Transport_Means"].value_counts()
# Out:
# Transport_Means
# school_bus    16145
# private       11362
# Name: count, dtype: int64

# %%
data1["Transport_Means"]=data1["Transport_Means"].fillna(data1["Transport_Means"].mode()[0])

# %%
data1["Transport_Means"].value_counts()
# Out:
# Transport_Means
# school_bus    19279
# private       11362
# Name: count, dtype: int64

# %%
data1.isnull().sum()
# Out:
# Gender                     0
# Ethnic_Group               0
# Parent_Educ                0
# Lunch_Type                 0
# Test_Prep                  0
# Parent_Marital_Status      0
# Practice_Sport             0
# Is_First_Child             0
# Nr_Siblings                0
# Transport_Means            0
# Wkly_Study_Hours         955
# Math_Score                 0
# Reading_Score              0
# Writing_Score              0
# dtype: int64

# %%
# # know i am working in the columns data1["Wkly_Study_Hours"]

# %%
data1["Wkly_Study_Hours"].isnull().sum()
# Out:
# np.int64(955)

# %%
data1["Wkly_Study_Hours"].value_counts()
# Out:
# Wkly_Study_Hours
# 5 - 10    16246
# < 5        8238
# > 10       5202
# Name: count, dtype: int64

# %%
type(data1["Wkly_Study_Hours"][8])
# Out:
# str

# %%
data1["Wkly_Study_Hours"]=data1["Wkly_Study_Hours"].fillna(data1["Wkly_Study_Hours"].mode()[0])

# %%
data1.isnull().sum()
# Out:
# Gender                   0
# Ethnic_Group             0
# Parent_Educ              0
# Lunch_Type               0
# Test_Prep                0
# Parent_Marital_Status    0
# Practice_Sport           0
# Is_First_Child           0
# Nr_Siblings              0
# Transport_Means          0
# Wkly_Study_Hours         0
# Math_Score               0
# Reading_Score            0
# Writing_Score            0
# dtype: int64

# %%
data1.head(30)
# Out:
#     Gender Ethnic_Group Parent_Educ    Lunch_Type  Test_Prep  \
# 0   female      group C     group C      standard       none
# 1   female      group C     group C      standard       none
# 2   female      group B     group B      standard       none
# 3     male      group A     group A  free/reduced       none
# 4     male      group C     group C      standard       none
# 5   female      group B     group B      standard       none
# 6   female      group B     group B      standard  completed
# 7     male      group B     group B  free/reduced       none
# 8     male      group D     group D  free/reduced  completed
# 9   female      group B     group B  free/reduced       none
# 10    male      group C     group C      standard       none
# 11    male      group D     group D      standard       none
# 12  female      group B     group B      standard       none
# 13    male      group A     group A      standard  completed
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 30641 non-null  object
#  1   Ethnic_Group           30641 non-null  object
#  2   Parent_Educ            30641 non-null  object
#  3   Lunch_Type             30641 non-null  object
#  4   Test_Prep              30641 non-null  object
#  5   Parent_Marital_Status  30641 non-null  object
#  6   Practice_Sport         30641 non-null  object
#  7   Is_First_Child         30641 non-null  object
#  8   Nr_Siblings            30641 non-null  int64
#  9   Transport_Means        30641 non-null  object
#  10  Wkly_Study_Hours       30641 non-null  object
#  11  Math_Score             30641 non-null  int64
#  12  Reading_Score          30641 non-null  int64
#  13  Writing_Score          30641 non-null  int64
# dtypes: int64(4), object(10)
# ...

# %%
# to. fillter dataset 
data1.to_csv("",index=Fa)
