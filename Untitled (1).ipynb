# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("indian_pharmaceutical_products_clean.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253973 entries, 0 to 253972
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   product_id              253973 non-null  int64
#  1   brand_name              253973 non-null  object
#  2   manufacturer            253973 non-null  object
#  3   price_inr               253973 non-null  float64
#  4   is_discontinued         253973 non-null  bool
#  5   dosage_form             253973 non-null  object
#  6   pack_size               231643 non-null  float64
#  7   pack_unit               231643 non-null  object
#  8   num_active_ingredients  253973 non-null  int64
#  9   primary_ingredient      253973 non-null  object
#  10  primary_strength        228775 non-null  object
#  11  active_ingredients      253973 non-null  object
#  12  therapeutic_class       253973 non-null  object
#  13  packaging_raw           253973 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# product_id                    0
# brand_name                    0
# manufacturer                  0
# price_inr                     0
# is_discontinued               0
# dosage_form                   0
# pack_size                 22330
# pack_unit                 22330
# num_active_ingredients        0
# primary_ingredient            0
# primary_strength          25198
# active_ingredients            0
# therapeutic_class             0
# packaging_raw                 0
# manufacturer_raw              0
# dtype: int64

# %%
data
# Out:
#         product_id                     brand_name  \
# 0                1       Augmentin 625 Duo Tablet
# 1                2            Azithral 500 Tablet
# 2                3               Ascoril LS Syrup
# 3                4           Allegra 120mg Tablet
# 4                5                 Avil 25 Tablet
# ...            ...                            ...
# 253968      253969  Ziyapod 100mg Oral Suspension
# 253969      253970            Zemhart 30mg Tablet
# 253970      253971              Zivex 25mg Tablet
# 253971      253972        ZI Fast 500mg Injection
# 253972      253973      Zyvocol 1% Dusting Powder
#
#                                  manufacturer  price_inr  is_discontinued  \
# 0        Glaxo SmithKline Pharmaceuticals Ltd     223.42            False
# 1                 Alembic Pharmaceuticals Ltd     132.36            False
# 2                Glenmark Pharmaceuticals Ltd     118.00            False
# ...

# %%
data["pack_size"].isnull().sum()
# Out:
# np.int64(22330)

# %%
data["pack_size"].value_counts()
# Out:
# pack_size
# 10.0     155077
# 30.0      12281
# 15.0       9525
# 100.0      8334
# 60.0       7719
#           ...
# 82.0          1
# 220.0         1
# 23.0          1
# 101.0         1
# 33.0          1
# Name: count, Length: 91, dtype: int64

# %%
type(data["pack_size"][67])
# Out:
# numpy.float64

# %%
# to find the null value  # who to find the null
# to means throught
data["pack_size"]=data["pack_size"].fillna(data["pack_size"].mean())

# %%
data["pack_size"]
# Out:
# 0          10.000000
# 1           5.000000
# 2         100.000000
# 3          10.000000
# 4          15.000000
#              ...
# 253968     30.000000
# 253969     10.000000
# 253970     10.000000
# 253971     18.988871
# 253972     75.000000
# Name: pack_size, Length: 253973, dtype: float64

# %%
data["pack_size"].isnull().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# product_id                    0
# brand_name                    0
# manufacturer                  0
# price_inr                     0
# is_discontinued               0
# dosage_form                   0
# pack_size                     0
# pack_unit                 22330
# num_active_ingredients        0
# primary_ingredient            0
# primary_strength          25198
# active_ingredients            0
# therapeutic_class             0
# packaging_raw                 0
# manufacturer_raw              0
# dtype: int64

# %%
#  now i am koring in the   the column name pack_unit

# %%
data["pack_unit"].isnull().sum()
# Out:
# np.int64(22330)

# %%
 # how to fill the null before filling the data 
# we chake the null and the fill the null value

# %%
type(data["pack_unit"][89])
# Out:
# str

# %%
data["pack_unit"].value_counts()
# Out:
# pack_unit
# strip     172122
# bottle     33772
# ml         14790
# tube        8241
# units       1424
# gm          1294
# Name: count, dtype: int64

# %%
  # to find the null by the help of the mean value

# %%
print((172122+33772+14790+8241+1424+1294)/6) # the nearest value o the data set 38607.166666666664
# Out:
# 38607.166666666664

# %%
# fill to find the

# %%
data["pack_unit"]=data["pack_unit"].fillna("38607")

# %%
data["pack_unit"]
# Out:
# 0          strip
# 1          strip
# 2         bottle
# 3          strip
# 4          strip
#            ...
# 253968    bottle
# 253969     strip
# 253970     strip
# 253971     38607
# 253972        gm
# Name: pack_unit, Length: 253973, dtype: object

# %%
data["pack_unit"]["pack_unit"].isnull().sum()
# Out:
# np.int64(0)

# %%
 # to couvert into the str in the int

# %%
data.isnull().sum()
# Out:
# product_id                    0
# brand_name                    0
# manufacturer                  0
# price_inr                     0
# is_discontinued               0
# dosage_form                   0
# pack_size                     0
# pack_unit                     0
# num_active_ingredients        0
# primary_ingredient            0
# primary_strength          25198
# active_ingredients            0
# therapeutic_class             0
# packaging_raw                 0
# manufacturer_raw              0
# dtype: int64

# %%
data["pack_unit"].isnull().sum()

# %%
# know i am working in the the column name primary_strength
# Out:
# str

# %%
data["primary_strength"]
# Out:
# 0            500mg
# 1            500mg
# 2         30mg/5ml
# 3            120mg
# 4             25mg
#             ...
# 253968       100mg
# 253969        30mg
# 253970        25mg
# 253971       500mg
# 253972         NaN
# Name: primary_strength, Length: 253973, dtype: object

# %%
data["primary_strength"].value_counts()
# Out:
# primary_strength
# 100mg         21632
# 200mg         19898
# 500mg         19437
# 50mg          14421
# 10mg          14402
#               ...
# 499.50mg          1
# 666mg             1
# 133.58mg          1
# 50mg/2.5ml        1
# 61mg              1
# Name: count, Length: 673, dtype: int64

# %%
data["primary_strength"].value_counts().mean() #np.float64(339.9331352154532)
# Out:
# np.float64(339.9331352154532)

# %%
data["primary_strength"].value_counts().iloc[50:70] # 160mg
# Out:
# primary_strength
# 1mg/5ml      429
# 0.4mg        412
# 0.2mg        401
# 7.5mg        387
# 0.3mg        379
# 1.5mg        362
# 450mg        342
# 160mg        319
# 125mg/5ml    311
# 10gm         295
# 400mg/5ml    292
# 325mg        272
# 12mg         270
# 250mg/5ml    266
# 4mg/5ml      219
# 1500mg       200
# 2000mg       199
# 10mg/5ml     192
# 1.25mg       184
# 24mg         173
# Name: count, dtype: int64

# %%
type(data["primary_strength"][89])
# Out:
# str

# %%
data["primary_strength"]=data["primary_strength"].fillna("160mg")

# %%
data.isnull().sum()
# Out:
# product_id                0
# brand_name                0
# manufacturer              0
# price_inr                 0
# is_discontinued           0
# dosage_form               0
# pack_size                 0
# pack_unit                 0
# num_active_ingredients    0
# primary_ingredient        0
# primary_strength          0
# active_ingredients        0
# therapeutic_class         0
# packaging_raw             0
# manufacturer_raw          0
# dtype: int64

# %%
# to  all null value are easly declear so we can see 
# after the to find the dublicate  value are drope

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#         product_id                     brand_name  \
# 0                1       Augmentin 625 Duo Tablet
# 1                2            Azithral 500 Tablet
# 2                3               Ascoril LS Syrup
# 3                4           Allegra 120mg Tablet
# 4                5                 Avil 25 Tablet
# ...            ...                            ...
# 253968      253969  Ziyapod 100mg Oral Suspension
# 253969      253970            Zemhart 30mg Tablet
# 253970      253971              Zivex 25mg Tablet
# 253971      253972        ZI Fast 500mg Injection
# 253972      253973      Zyvocol 1% Dusting Powder
#
#                                  manufacturer  price_inr  is_discontinued  \
# 0        Glaxo SmithKline Pharmaceuticals Ltd     223.42            False
# 1                 Alembic Pharmaceuticals Ltd     132.36            False
# 2                Glenmark Pharmaceuticals Ltd     118.00            False
# ...

# %%
data.isnull().sum()
# Out:
# product_id                0
# brand_name                0
# manufacturer              0
# price_inr                 0
# is_discontinued           0
# dosage_form               0
# pack_size                 0
# pack_unit                 0
# num_active_ingredients    0
# primary_ingredient        0
# primary_strength          0
# active_ingredients        0
# therapeutic_class         0
# packaging_raw             0
# manufacturer_raw          0
# dtype: int64

# %%
 # fillnaly fillte  the columns 
# the after cleaning the data csv file()
data.to_csv("after_fillter_indian_pharmaceutical_products_clean.csv",index=False)
