# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv("Airbnb_Open_Data 2.csv")
data
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/3275820383.py:4: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("Airbnb_Open_Data 2.csv")
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# ...

# %%
data.head(6)
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified               289
# host name                            406
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# ...

# %%
data=data.dropna(subset=["NAME"])

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
data.isnull().sum()
# Out:
# id                                     0
# NAME                                   0
# host id                                0
# host_identity_verified               277
# host name                            400
# neighbourhood group                   27
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              527
# country code                         123
# instant_bookable                      97
# cancellation_policy                   71
# room type                              0
# Construction year                    205
# price                                244
# service fee                          273
# minimum nights                       403
# number of reviews                    182
# last review                        15857
# reviews per month                  15843
# review rate number                   318
# calculated host listings count       318
# ...

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
# who see the all coloumn name

# %%
# 1) print(dat.columns())
print(data.columns)
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
#2) the data will 
for col in data.columns:
    print(col)
# Out:
# id
# NAME
# host id
# host_identity_verified
# host name
# neighbourhood group
# neighbourhood
# lat
# long
# country
# country code
# instant_bookable
# cancellation_policy
# room type
# Construction year
# price
# service fee
# minimum nights
# number of reviews
# last review
# reviews per month
# review rate number
# calculated host listings count
# availability 365
# house_rules
# license

# %%
print(list(data.columns))
# Out:
# ['id', 'NAME', 'host id', 'host_identity_verified', 'host name', 'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country', 'country code', 'instant_bookable', 'cancellation_policy', 'room type', 'Construction year', 'price', 'service fee', 'minimum nights', 'number of reviews', 'last review', 'reviews per month', 'review rate number', 'calculated host listings count', 'availability 365', 'house_rules', 'license']

# %%
# who to cheak the data with the data of column
data.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
data.head(30).T
# Out:
#                                                                                0   \
# id                                                                        1001254
# NAME                                           Clean & quiet apt home by the park
# host id                                                               80014485718
# host_identity_verified                                                unconfirmed
# host name                                                                Madaline
# neighbourhood group                                                      Brooklyn
# neighbourhood                                                          Kensington
# lat                                                                      40.64749
# long                                                                    -73.97237
# country                                                             United States
# ...

# %%
data.isnull().sum()
# Out:
# id                                     0
# NAME                                   0
# host id                                0
# host_identity_verified               277
# host name                            400
# neighbourhood group                   27
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              527
# country code                         123
# instant_bookable                      97
# cancellation_policy                   71
# room type                              0
# Construction year                    205
# price                                244
# service fee                          273
# minimum nights                       403
# number of reviews                    182
# last review                        15857
# reviews per month                  15843
# review rate number                   318
# calculated host listings count       318
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102349 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102349 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102349 non-null  int64
#  3   host_identity_verified          102072 non-null  object
#  4   host name                       101949 non-null  object
#  5   neighbourhood group             102322 non-null  object
#  6   neighbourhood                   102333 non-null  object
#  7   lat                             102341 non-null  float64
#  8   long                            102341 non-null  float64
#  9   country                         101822 non-null  object
#  10  country code                    102226 non-null  object
#  11  instant_bookable                102252 non-null  object
# ...

# %%
list(data.columns)
# Out:
# ['id',
#  'NAME',
#  'host id',
#  'host_identity_verified',
#  'host name',
#  'neighbourhood group',
#  'neighbourhood',
#  'lat',
#  'long',
#  'country',
#  'country code',
#  'instant_bookable',
#  'cancellation_policy',
#  'room type',
#  'Construction year',
#  'price',
#  'service fee',
#  'minimum nights',
#  'number of reviews',
#  'last review',
#  'reviews per month',
#  'review rate number',
#  'calculated host listings count',
#  'availability 365',
#  'house_rules',
#  'license']

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
# to take the column name data .who many data or column ara take
keep_column_data=['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews','last review']
drop_column_data=[ 'reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license']

# %%
print(keep_column_data)
# Out:
# ['id', 'NAME', 'host id', 'host_identity_verified', 'host name', 'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country', 'country code', 'instant_bookable', 'cancellation_policy', 'room type', 'Construction year', 'price', 'service fee', 'minimum nights', 'number of reviews', 'last review']

# %%
print(drop_column_data)
# Out:
# ['reviews per month', 'review rate number', 'calculated host listings count', 'availability 365', 'house_rules', 'license']

# %%
data[keep_column_data]
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
data[drop_column_data]
# Out:
#         reviews per month  review rate number  calculated host listings count  \
# 0                    0.21                 4.0                             6.0
# 1                    0.38                 4.0                             2.0
# 2                     NaN                 5.0                             1.0
# 4                    0.10                 3.0                             1.0
# 5                    0.59                 3.0                             1.0
# ...                   ...                 ...                             ...
# 102594                NaN                 3.0                             1.0
# 102595               0.02                 2.0                             2.0
# 102596                NaN                 5.0                             1.0
# 102597               0.10                 3.0                             1.0
# 102598                NaN                 3.0                             1.0
#
# ...

# %%
# To cheak the no of column the( data[keep_column_data] data[drop_column_data])
# so we cam aplide the data 
len(keep_column_data)
# Out:
# 20

# %%
len(drop_column_data)
# Out:
# 6

# %%
 # the total no of the column data set 
len(data.columns)
# the i divived the correct form the acording the columns
# Out:
# 26

# %%
 # its throught easly cheak the the no of rows and no of column
 data.shape
# Out:
# (102349, 26)

# %% [markdown]
# # the first methode the filtering data

# %%
df=data[keep_column_data]

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
# the secound methode to drop the data easly extra column
dp=data[drop_column_data]

# %%
dp
# Out:
#         reviews per month  review rate number  calculated host listings count  \
# 0                    0.21                 4.0                             6.0
# 1                    0.38                 4.0                             2.0
# 2                     NaN                 5.0                             1.0
# 4                    0.10                 3.0                             1.0
# 5                    0.59                 3.0                             1.0
# ...                   ...                 ...                             ...
# 102594                NaN                 3.0                             1.0
# 102595               0.02                 2.0                             2.0
# 102596                NaN                 5.0                             1.0
# 102597               0.10                 3.0                             1.0
# 102598                NaN                 3.0                             1.0
#
# ...

# %%
# drop the coloumns like the single column so
data 
data.drop(columns=["license"])
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
# to cheak the no row and the number of the columns 
data.shape
#  the no row and the number of the columns  are same why beacuse (inplace=True) not  used that whys
# Out:
# (102349, 26)

# %%
# data.drop(columns=["license"],inplace=True)

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
# yes the columns data easly delete in the main data
data.shape
# Out:
# (102349, 26)

# %% [markdown]
# # the secound methode to drop the data easly extra column

# %%
data.drop(columns=drop_column_data,inplace=True)
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/1915097555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=drop_column_data,inplace=True)

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
 # to cheak the columns name
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
data.shape
# Out:
# (102349, 20)

# %%
# that's is the perfectaly work in the drops the columns means unuable data 
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
# the name columns name gives the upper case (NAME) to convert into the lower case by using.
# the rename function 
data.rename(columns={'NAME': "name"},inplace=True)
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/662229266.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'NAME': "name"},inplace=True)

# %%
# the convert the upper case to the lower sace data
data
# Out:
#              id                                              name  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
# who to convert into the all columns in the upper case(it is the advance )
for i in data.columns:
    print(i.upper())
# Out:
# ID
# NAME
# HOST ID
# HOST_IDENTITY_VERIFIED
# HOST NAME
# NEIGHBOURHOOD GROUP
# NEIGHBOURHOOD
# LAT
# LONG
# COUNTRY
# COUNTRY CODE
# INSTANT_BOOKABLE
# CANCELLATION_POLICY
# ROOM TYPE
# CONSTRUCTION YEAR
# PRICE
# SERVICE FEE
# MINIMUM NIGHTS
# NUMBER OF REVIEWS
# LAST REVIEW

# %%
# who to convert into the all columns in the lower case(it is the advance )
for i in data.columns:
    print(i.lower())
# Out:
# id
# name
# host id
# host_identity_verified
# host name
# neighbourhood group
# neighbourhood
# lat
# long
# country
# country code
# instant_bookable
# cancellation_policy
# room type
# construction year
# price
# service fee
# minimum nights
# number of reviews
# last review

# %%
# who to convert into the all columns in the lower capitalize(it is the advance )
for i in data.columns:
    print(i.capitalize())
# Out:
# Id
# Name
# Host id
# Host_identity_verified
# Host name
# Neighbourhood group
# Neighbourhood
# Lat
# Long
# Country
# Country code
# Instant_bookable
# Cancellation_policy
# Room type
# Construction year
# Price
# Service fee
# Minimum nights
# Number of reviews
# Last review

# %%
 # to change the all columns in the upper to  convert the data 
#first_of make the empty column data
new_columns_list_form=[]
for i in data.columns:
    new_columns_list_form.append(i.upper())

# %%
new_columns_list_form
# to cheak the columns witch type
# Out:
# ['ID',
#  'NAME',
#  'HOST ID',
#  'HOST_IDENTITY_VERIFIED',
#  'HOST NAME',
#  'NEIGHBOURHOOD GROUP',
#  'NEIGHBOURHOOD',
#  'LAT',
#  'LONG',
#  'COUNTRY',
#  'COUNTRY CODE',
#  'INSTANT_BOOKABLE',
#  'CANCELLATION_POLICY',
#  'ROOM TYPE',
#  'CONSTRUCTION YEAR',
#  'PRICE',
#  'SERVICE FEE',
#  'MINIMUM NIGHTS',
#  'NUMBER OF REVIEWS',
#  'LAST REVIEW']

# %%
type(new_columns_list_form)
# Out:
# list

# %%
new_data=data.copy()

# %%
new_data.columns=new_columns_list_form

# %%
new_data
# Out:
#              ID                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             HOST ID HOST_IDENTITY_VERIFIED    HOST NAME NEIGHBOURHOOD GROUP  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
 # secound form upper case 
for i in data.columns:
    print(i)
# Out:
# id
# name
# host id
# host_identity_verified
# host name
# neighbourhood group
# neighbourhood
# lat
# long
# country
# country code
# instant_bookable
# cancellation_policy
# room type
# Construction year
# price
# service fee
# minimum nights
# number of reviews
# last review

# %%
new_column=[]
for i in data.columns:
    new_column.append(i.upper())

# %%
type(new_column)
# Out:
# list

# %%
new_copy_data=data.copy()
new_copy_data.columns=new_column

# %%
x=new_copy_data

# %%
x.columns
# Out:
# Index(['ID', 'NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS', 'LAST REVIEW'],
#       dtype='object')

# %% [markdown]
# # our prectiees thatwhy we wil convert the  lower case

# %%
# our prectiees thatwhy we wil convert the  lower case
for col in x.columns:
    print(col)
# Out:
# ID
# NAME
# HOST ID
# HOST_IDENTITY_VERIFIED
# HOST NAME
# NEIGHBOURHOOD GROUP
# NEIGHBOURHOOD
# LAT
# LONG
# COUNTRY
# COUNTRY CODE
# INSTANT_BOOKABLE
# CANCELLATION_POLICY
# ROOM TYPE
# CONSTRUCTION YEAR
# PRICE
# SERVICE FEE
# MINIMUM NIGHTS
# NUMBER OF REVIEWS
# LAST REVIEW

# %%
#So follwed in the steps
data_lower=[]
for i in x.columns:
    data_lower.append(i.lower())
data_lower
# Out:
# ['id',
#  'name',
#  'host id',
#  'host_identity_verified',
#  'host name',
#  'neighbourhood group',
#  'neighbourhood',
#  'lat',
#  'long',
#  'country',
#  'country code',
#  'instant_bookable',
#  'cancellation_policy',
#  'room type',
#  'construction year',
#  'price',
#  'service fee',
#  'minimum nights',
#  'number of reviews',
#  'last review']

# %%
# the will copy the upper wala so 
copy_data=x.copy()
copy_data.columns=data_lower

# %%
copy_data
# Out:
#              id                                              name  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %% [markdown]
#  # to convert in  the all column in the each columns name in the  capatilize

# %%
copy_data.columns
# Out:
# Index(['id', 'name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
capiti_list=[]
for i in copy_data.columns:
    capiti_list.append(i.capitalize())

# %%
capiti_list
# Out:
# ['Id',
#  'Name',
#  'Host id',
#  'Host_identity_verified',
#  'Host name',
#  'Neighbourhood group',
#  'Neighbourhood',
#  'Lat',
#  'Long',
#  'Country',
#  'Country code',
#  'Instant_bookable',
#  'Cancellation_policy',
#  'Room type',
#  'Construction year',
#  'Price',
#  'Service fee',
#  'Minimum nights',
#  'Number of reviews',
#  'Last review']

# %%
cap_copy=copy_data.copy()
cap_copy.columns=capiti_list

# %%
cap_copy
# Out:
#              Id                                              Name  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             Host id Host_identity_verified    Host name Neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
data1.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 data1.info()
#
# NameError: name 'data1' is not defined

# %%
# in next work in the upper case the columns data
# so
data1=new_data

# %%
data1
# Out:
#              ID                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             HOST ID HOST_IDENTITY_VERIFIED    HOST NAME NEIGHBOURHOOD GROUP  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#delete the dupplicate vaues accorng to the data["ID"] columns

# %%
# and delete the dupplicate vaues 
data1["ID"].value_counts()
# Out:
# ID
# 35607902    2
# 35607349    2
# 35606797    2
# 35606245    2
# 35605693    2
#            ..
# 57356371    1
# 57356923    1
# 57357476    1
# 57358028    1
# 57358580    1
# Name: count, Length: 101808, dtype: int64

# %%
data1["NAME"].value_counts()
# Out:
# NAME
# Home away from home                                  33
# Hillside Hotel                                       30
# Water View King Bed Hotel Room                       30
# Brooklyn Apartment                                   27
# New york Multi-unit building                         27
#                                                      ..
# For all classical lover's 4                           1
# "San-Paraíso" 80s curated Retro 3 Bedroom LES Pad     1
# SUITE- PRIVATE 1/2 BATH, 4 BEDS IN WILLIAMSBURG!!     1
# Spacious bedroom in Washington Heights                1
# Stunning Rare Garden Family Home w/Loft! #10303       1
# Name: count, Length: 61281, dtype: int64

# %%
data1["HOST ID"].value_counts()
# Out:
# HOST ID
# 7431680152     2
# 57770451783    2
# 65331079885    2
# 27445218777    2
# 75670762826    2
#               ..
# 11038605149    1
# 29320426760    1
# 14430571516    1
# 56457739998    1
# 60176837202    1
# Name: count, Length: 101808, dtype: int64

# %%
data1["HOST_IDENTITY_VERIFIED"].value_counts().sum()
# Out:
# np.int64(102072)

# %%
data1["HOST NAME"].value_counts()
# Out:
# HOST NAME
# Michael            880
# David              762
# John               580
# Alex               544
# Sonder (NYC)       515
#                   ...
# Loocid               1
# John J.              1
# Yaser                1
# Denae                1
# Ashley Michelle      1
# Name: count, Length: 13183, dtype: int64

# %%
# to find the each column dupplication values()

data1.duplicated().head()
# Out:
# 0    False
# 1    False
# 2    False
# 4    False
# 5    False
# dtype: bool

# %%
data1.duplicated().tail()
# Out:
# 102594    True
# 102595    True
# 102596    True
# 102597    True
# 102598    True
# dtype: bool

# %%
data1.duplicated().sum()
# Out:
# np.int64(541)

# %%
data=data1.duplicated().value_counts()

# %% [markdown]
# # who to delete the duplicated values

# %%
data1.drop_duplicates(inplace=True)

# %%
data1.duplicated().sum()
# Out:
# np.int64(0)

# %%
data1
# Out:
#               ID                                              NAME  \
# 0        1001254                Clean & quiet apt home by the park
# 1        1002102                             Skylit Midtown Castle
# 2        1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4        1003689  Entire Apt: Spacious Studio/Loft by central park
# 5        1004098         Large Cozy 1 BR Apartment In Midtown East
# ...          ...                                               ...
# 102053  57365208               Cozy bright room near Prospect Park
# 102054  57365760         Private Bedroom with Amazing Rooftop View
# 102055  57366313     Pretty Brooklyn One-Bedroom for 2 to 4 people
# 102056  57366865        Room & private bathroom in historic Harlem
# 102057  57367417                                   Rosalee Stewart
#
#             HOST ID HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP  \
# 0       80014485718            unconfirmed  Madaline            Brooklyn
# ...

# %% [markdown]
# # i want to cheak the each columns duplicate value present or not

# %%
data1["ID"].value_counts()
# Out:
# ID
# 57358580    1
# 57358028    1
# 57357476    1
# 57356923    1
# 57356371    1
#            ..
# 1004098     1
# 1003689     1
# 1002403     1
# 1002102     1
# 1001254     1
# Name: count, Length: 101808, dtype: int64

# %%
data1.columns
# Out:
# Index(['ID', 'NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS', 'LAST REVIEW'],
#       dtype='object')

# %%
data1["NAME"].value_counts()
# Out:
# NAME
# Home away from home                                 33
# Hillside Hotel                                      30
# Water View King Bed Hotel Room                      30
# Brooklyn Apartment                                  27
# New york Multi-unit building                        27
#                                                     ..
# West Village Nest - Superhost                        1
# Wonderful Guest Bedroom in Manhattan for SINGLES     1
# Lovely Room 1, Garden, Best Area, Legal rental       1
# Central Manhattan/near Broadway                      1
# Beautiful 1br on Upper West Side                     1
# Name: count, Length: 61281, dtype: int64

# %%
data1["HOST ID"].value_counts()
# Out:
# HOST ID
# 60176837202    1
# 56457739998    1
# 14430571516    1
# 29320426760    1
# 11038605149    1
#               ..
# 45498551794    1
# 92037596077    1
# 78829239556    1
# 52335172823    1
# 80014485718    1
# Name: count, Length: 101808, dtype: int64

# %%
data1["HOST_IDENTITY_VERIFIED"].value_counts()
# Out:
# HOST_IDENTITY_VERIFIED
# unconfirmed    50827
# verified       50704
# Name: count, dtype: int64

# %%
data1['HOST NAME'].value_counts()
# Out:
# HOST NAME
# Michael             877
# David               759
# John                576
# Alex                541
# Sonder (NYC)        515
#                    ...
# Evrim                 1
# Nathanael             1
# Serkan                1
# Alankrit              1
# Sebastien Rafael      1
# Name: count, Length: 13183, dtype: int64

# %%
data1['NEIGHBOURHOOD GROUP'].value_counts()
# Out:
# NEIGHBOURHOOD GROUP
# Manhattan        43454
# Brooklyn         41522
# Queens           13169
# Bronx             2686
# Staten Island      948
# brookln              1
# manhatan             1
# Name: count, dtype: int64

# %%
data1['NEIGHBOURHOOD'].value_counts()
# Out:
# NEIGHBOURHOOD
# Bedford-Stuyvesant        7874
# Williamsburg              7705
# Harlem                    5425
# Bushwick                  4945
# Hell's Kitchen            3939
#                           ...
# Rossville                    3
# Gerritsen Beach              3
# Fort Wadsworth               2
# Glen Oaks                    2
# Chelsea, Staten Island       1
# Name: count, Length: 224, dtype: int64

# %%
data1['LAT'].value_counts()
# Out:
# LAT
# 40.76411    35
# 40.71813    32
# 40.76125    28
# 40.73756    26
# 40.72440    25
#             ..
# 40.77165     1
# 40.85125     1
# 40.80860     1
# 40.64095     1
# 40.69672     1
# Name: count, Length: 21975, dtype: int64

# %%
data1["LONG"].value_counts()
# Out:
# LONG
# -73.99371    43
# -73.95350    38
# -73.95427    37
# -73.94791    37
# -73.95677    34
#              ..
# -73.80415     1
# -73.90284     1
# -74.03288     1
# -73.87523     1
# -74.13181     1
# Name: count, Length: 17764, dtype: int64

# %%
data1['COUNTRY'].value_counts()
# Out:
# COUNTRY
# United States    101281
# Name: count, dtype: int64

# %%
data1['INSTANT_BOOKABLE'].value_counts()
# Out:
# INSTANT_BOOKABLE
# False    51066
# True     50645
# Name: count, dtype: int64

# %%
data1['CANCELLATION_POLICY'].value_counts()
# Out:
# CANCELLATION_POLICY
# moderate    34081
# strict      33839
# flexible    33817
# Name: count, dtype: int64

# %%
data1['ROOM TYPE'].value_counts()
# Out:
# ROOM TYPE
# Entire home/apt    53303
# Private room       46188
# Shared room         2202
# Hotel room           115
# Name: count, dtype: int64

# %%
data1['CONSTRUCTION YEAR'].value_counts()
# Out:
# CONSTRUCTION YEAR
# 2014.0    5204
# 2006.0    5181
# 2008.0    5178
# 2019.0    5165
# 2009.0    5126
# 2010.0    5125
# 2020.0    5120
# 2022.0    5103
# 2012.0    5088
# 2005.0    5087
# 2003.0    5083
# 2007.0    5075
# 2015.0    5059
# 2017.0    5025
# 2018.0    5012
# 2011.0    5012
# 2021.0    5004
# 2004.0    4992
# 2013.0    4990
# 2016.0    4974
# Name: count, dtype: int64

# %%
data1['PRICE'].value_counts()
# Out:
# PRICE
# $206       135
# $1,056     130
# $481       129
# $833       127
# $573       126
#           ...
# $369        57
# $923        56
# $786        54
# $89         53
# $187        52
# Name: count, Length: 1151, dtype: int64

# %%
data1['SERVICE FEE'].value_counts()
# Out:
# SERVICE FEE
# $216     523
# $41      518
# $177     515
# $81      513
# $57      508
#         ...
# $73      385
# $58      379
# $67      377
# $10      264
# $240     247
# Name: count, Length: 231, dtype: int64

# %%
data1['MINIMUM NIGHTS'].value_counts()
# Out:
# MINIMUM NIGHTS
#  1.0      25230
#  2.0      23436
#  3.0      15997
#  30.0     11532
#  4.0       6595
#           ...
# -125.0        1
#  125.0        1
#  34.0         1
#  458.0        1
#  825.0        1
# Name: count, Length: 151, dtype: int64

# %%
data1['NUMBER OF REVIEWS'].value_counts()
# Out:
# NUMBER OF REVIEWS
# 0.0      15637
# 1.0      10324
# 2.0       7115
# 3.0       5335
# 4.0       4115
#          ...
# 797.0        1
# 592.0        1
# 567.0        1
# 648.0        1
# 367.0        1
# Name: count, Length: 475, dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
#  # # remove the nan value  from the dataset
# #  cleanig  individual columns

# %%
data1[100:5000]
# Out:
#            ID                                               NAME      HOST ID  \
# 115   1064851  2 BR / 2 Bath Duplex Apt with patio! East Village  63842204720
# 116   1065403                 NYC fabulous views Manhattan's eye  14374368872
# 117   1065955                2 story family home in Williamsburg  40328778117
# 119   1067060             Great Large 1 BR apt  in East Village!  27506185339
# 120   1067612  Eveland Private Bed & Living Room w/ Own Entrance  25474679480
# ...       ...                                                ...          ...
# 5053  3792108                          Cozy Single private room.  83060832028
# 5054  3792660                   Sunny Private Apt in Ditmas Park  27571403000
# 5055  3793213                  2BR Apartment in Doorman Building  94214396849
# 5056  3793765      1 Bedroom  Apartment close to Northwell & JFK  92596272687
# 5057  3794317                             Spacious 2BR townhouse  79388278716
#
# ...

# %%
data1.isna().sum()
# Out:
# ID                            0
# NAME                          0
# HOST ID                       0
# HOST_IDENTITY_VERIFIED      277
# HOST NAME                   398
# NEIGHBOURHOOD GROUP          27
# NEIGHBOURHOOD                16
# LAT                           8
# LONG                          8
# COUNTRY                     527
# COUNTRY CODE                123
# INSTANT_BOOKABLE             97
# CANCELLATION_POLICY          71
# ROOM TYPE                     0
# CONSTRUCTION YEAR           205
# PRICE                       244
# SERVICE FEE                 273
# MINIMUM NIGHTS              394
# NUMBER OF REVIEWS           182
# LAST REVIEW               15796
# dtype: int64

# %%
data1.isnull().sum()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101808 entries, 0 to 102057
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ID                      101808 non-null  int64
#  1   NAME                    101808 non-null  object
#  2   HOST ID                 101808 non-null  int64
#  3   HOST_IDENTITY_VERIFIED  101531 non-null  object
#  4   HOST NAME               101410 non-null  object
#  5   NEIGHBOURHOOD GROUP     101781 non-null  object
#  6   NEIGHBOURHOOD           101792 non-null  object
#  7   LAT                     101800 non-null  float64
#  8   LONG                    101800 non-null  float64
#  9   COUNTRY                 101281 non-null  object
#  10  COUNTRY CODE            101685 non-null  object
#  11  INSTANT_BOOKABLE        101711 non-null  object
#  12  CANCELLATION_POLICY     101737 non-null  object
#  13  ROOM TYPE               101808 non-null  object
# ...

# %%
# data1.drop(columns=["LAST REVIEW"],inplace=True)

# %%
#  to work in the columns name LAST REVIEW  the aplied the function ffillna
data1["LAST REVIEW"].fillna(method="ffill",inplace=True)
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/3800275610.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1["LAST REVIEW"].fillna(method="ffill",inplace=True)
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/3800275610.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["LAST REVIEW"].fillna(method="ffill",inplace=True)

# %%
data1.isna().sum()
# Out:
# ID                          0
# NAME                        0
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    277
# HOST NAME                 398
# NEIGHBOURHOOD GROUP        27
# NEIGHBOURHOOD              16
# LAT                         8
# LONG                        8
# COUNTRY                   527
# COUNTRY CODE              123
# INSTANT_BOOKABLE           97
# CANCELLATION_POLICY        71
# ROOM TYPE                   0
# CONSTRUCTION YEAR         205
# PRICE                     244
# SERVICE FEE               273
# MINIMUM NIGHTS            394
# NUMBER OF REVIEWS         182
# LAST REVIEW                 0
# dtype: int64

# %%
data1.isna().sum()
# Out:
# ID                          0
# NAME                        0
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    277
# HOST NAME                 398
# NEIGHBOURHOOD GROUP        27
# NEIGHBOURHOOD              16
# LAT                         8
# LONG                        8
# COUNTRY                   527
# COUNTRY CODE              123
# INSTANT_BOOKABLE           97
# CANCELLATION_POLICY        71
# ROOM TYPE                   0
# CONSTRUCTION YEAR         205
# PRICE                     244
# SERVICE FEE               273
# MINIMUM NIGHTS            394
# NUMBER OF REVIEWS         182
# LAST REVIEW                 0
# dtype: int64

# %%
data2=data1.dropna()

# %%
# yeshe karke solve kar sakte hay but me chahta hu ki mera column data kam se kam loss ho
#We can solve it this way, but I want my column data to have minimal loss and remain correct.

# %%
data2.isnull().sum()
# Out:
# ID                        0
# NAME                      0
# HOST ID                   0
# HOST_IDENTITY_VERIFIED    0
# HOST NAME                 0
# NEIGHBOURHOOD GROUP       0
# NEIGHBOURHOOD             0
# LAT                       0
# LONG                      0
# COUNTRY                   0
# COUNTRY CODE              0
# INSTANT_BOOKABLE          0
# CANCELLATION_POLICY       0
# ROOM TYPE                 0
# CONSTRUCTION YEAR         0
# PRICE                     0
# SERVICE FEE               0
# MINIMUM NIGHTS            0
# NUMBER OF REVIEWS         0
# LAST REVIEW               0
# dtype: int64

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99342 entries, 0 to 102040
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      99342 non-null  int64
#  1   NAME                    99342 non-null  object
#  2   HOST ID                 99342 non-null  int64
#  3   HOST_IDENTITY_VERIFIED  99342 non-null  object
#  4   HOST NAME               99342 non-null  object
#  5   NEIGHBOURHOOD GROUP     99342 non-null  object
#  6   NEIGHBOURHOOD           99342 non-null  object
#  7   LAT                     99342 non-null  float64
#  8   LONG                    99342 non-null  float64
#  9   COUNTRY                 99342 non-null  object
#  10  COUNTRY CODE            99342 non-null  object
#  11  INSTANT_BOOKABLE        99342 non-null  object
#  12  CANCELLATION_POLICY     99342 non-null  object
#  13  ROOM TYPE               99342 non-null  object
# ...

# %%
# that"s why

# %% [markdown]
# # cleanig individual columns

# %%
data1.isna().sum()
# Out:
# ID                          0
# NAME                        0
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    277
# HOST NAME                 398
# NEIGHBOURHOOD GROUP        27
# NEIGHBOURHOOD              16
# LAT                         8
# LONG                        8
# COUNTRY                   527
# COUNTRY CODE              123
# INSTANT_BOOKABLE           97
# CANCELLATION_POLICY        71
# ROOM TYPE                   0
# CONSTRUCTION YEAR         205
# PRICE                     244
# SERVICE FEE               273
# MINIMUM NIGHTS            394
# NUMBER OF REVIEWS         182
# LAST REVIEW                 0
# dtype: int64

# %% [markdown]
#  # cleanig individual columns(HOST_IDENTITY_VERIFIED)

# %%
data1["HOST_IDENTITY_VERIFIED"] # first the data will convert the upper case form
# Out:
# 0         unconfirmed
# 1            verified
# 2                 NaN
# 4            verified
# 5            verified
#              ...
# 102053    unconfirmed
# 102054       verified
# 102055       verified
# 102056    unconfirmed
# 102057       verified
# Name: HOST_IDENTITY_VERIFIED, Length: 101808, dtype: object

# %%
data1["HOST_IDENTITY_VERIFIED"].str.upper() # the main data set in convert
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 2                 NaN
# 4            VERIFIED
# 5            VERIFIED
#              ...
# 102053    UNCONFIRMED
# 102054       VERIFIED
# 102055       VERIFIED
# 102056    UNCONFIRMED
# 102057       VERIFIED
# Name: HOST_IDENTITY_VERIFIED, Length: 101808, dtype: object

# %%
data1["HOST_IDENTITY_VERIFIED"]=data1["HOST_IDENTITY_VERIFIED"].str.upper() # the main data set in convert

# %%
data1
# Out:
#               ID                                              NAME  \
# 0        1001254                Clean & quiet apt home by the park
# 1        1002102                             Skylit Midtown Castle
# 2        1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4        1003689  Entire Apt: Spacious Studio/Loft by central park
# 5        1004098         Large Cozy 1 BR Apartment In Midtown East
# ...          ...                                               ...
# 102053  57365208               Cozy bright room near Prospect Park
# 102054  57365760         Private Bedroom with Amazing Rooftop View
# 102055  57366313     Pretty Brooklyn One-Bedroom for 2 to 4 people
# 102056  57366865        Room & private bathroom in historic Harlem
# 102057  57367417                                   Rosalee Stewart
#
#             HOST ID HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP  \
# 0       80014485718            UNCONFIRMED  Madaline            Brooklyn
# ...

# %%
data1.isnull().sum()
# Out:
# ID                          0
# NAME                        0
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    277
# HOST NAME                 398
# NEIGHBOURHOOD GROUP        27
# NEIGHBOURHOOD              16
# LAT                         8
# LONG                        8
# COUNTRY                   527
# COUNTRY CODE              123
# INSTANT_BOOKABLE           97
# CANCELLATION_POLICY        71
# ROOM TYPE                   0
# CONSTRUCTION YEAR         205
# PRICE                     244
# SERVICE FEE               273
# MINIMUM NIGHTS            394
# NUMBER OF REVIEWS         182
# LAST REVIEW                 0
# dtype: int64

# %%
 # to work in the (INSTANT_BOOKABLE) columns opration appied
# so do
data1["INSTANT_BOOKABLE"].value_counts()
# Out:
# INSTANT_BOOKABLE
# False    51066
# True     50645
# Name: count, dtype: int64

# %%
data1["INSTANT_BOOKABLE"]
# Out:
# 0         False
# 1         False
# 2          True
# 4         False
# 5          True
#           ...
# 102053     True
# 102054    False
# 102055     True
# 102056     True
# 102057    False
# Name: INSTANT_BOOKABLE, Length: 101808, dtype: object

# %%
# the columns (data1[" INSTANT_BOOKABLE "] ) given data(true,false) in the data convert into the 0 and 1 form
data1["INSTANT_BOOKABLE"]=data1["INSTANT_BOOKABLE"].apply(lambda x:1 if x==True else 0)

# %%
data1["INSTANT_BOOKABLE"].dtype
# Out:
# dtype('int64')

# %%
data1.head(13)
# Out:
#          ID                                              NAME      HOST ID  \
# 0   1001254                Clean & quiet apt home by the park  80014485718
# 1   1002102                             Skylit Midtown Castle  52335172823
# 2   1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 4   1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5   1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 6   1004650                                   BlissArtsSpace!  61300605564
# 7   1005202                                   BlissArtsSpace!  90821839709
# 8   1005754                   Large Furnished Room Near B'way  79384379533
# 9   1006307                Cozy Clean Guest Room - Family Apt  75527839483
# 10  1006859                Cute & Cozy Lower East Side 1 bdrm   1280143094
# 11  1007411                  Beautiful 1br on Upper West Side  18824631834
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101808 entries, 0 to 102057
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ID                      101808 non-null  int64
#  1   NAME                    101808 non-null  object
#  2   HOST ID                 101808 non-null  int64
#  3   HOST_IDENTITY_VERIFIED  101531 non-null  object
#  4   HOST NAME               101410 non-null  object
#  5   NEIGHBOURHOOD GROUP     101781 non-null  object
#  6   NEIGHBOURHOOD           101792 non-null  object
#  7   LAT                     101800 non-null  float64
#  8   LONG                    101800 non-null  float64
#  9   COUNTRY                 101281 non-null  object
#  10  COUNTRY CODE            101685 non-null  object
#  11  INSTANT_BOOKABLE        101808 non-null  int64
#  12  CANCELLATION_POLICY     101737 non-null  object
#  13  ROOM TYPE               101808 non-null  object
# ...

# %% [markdown]
# # who to cheak the each columns data type By the type function throught

# %%
type(data1["ID"][78])
# Out:
# numpy.int64

# %%
type(data1["NAME"][6])
# Out:
# str

# %%
type(data1["HOST ID"][9])
# Out:
# numpy.int64

# %%
type(data1["HOST_IDENTITY_VERIFIED"][5000])
# Out:
# str

# %%
type(data1["HOST NAME"][90000])
# Out:
# str

# %%
type(data1["NEIGHBOURHOOD GROUP"][90000])
# Out:
# str

# %%
type(data1["NEIGHBOURHOOD"][56000])
# Out:
# str

# %%
type(data1["LAT"][56000])
# Out:
# numpy.float64

# %%
type(data1["LONG"][56000])
# Out:
# numpy.float64

# %%
type(data1["COUNTRY"][56000])
# Out:
# str

# %%
type(data1["COUNTRY CODE"][56000])
# Out:
# str

# %%
type(data1["INSTANT_BOOKABLE"][56000])
# Out:
# numpy.int64

# %%
type(data1["CANCELLATION_POLICY"][56000])
# Out:
# str

# %%
type(data1["ROOM TYPE"][56000])
# Out:
# str

# %%
type(data1["CONSTRUCTION YEAR"][80000])
# Out:
# numpy.float64

# %%
type(data1["PRICE"][90000])
# Out:
# str

# %%
type(data1["SERVICE FEE"][90000])
# Out:
# str

# %%
type(data1["MINIMUM NIGHTS"][90000])
# Out:
# numpy.float64

# %%
type(data1["NUMBER OF REVIEWS"][89000])
# Out:
# numpy.float64

# %%
type(data1["LAST REVIEW"][90090])
# Out:
# str

# %%
# i know data type in the each column

# %% [markdown]
# # after that working in the price column  Ad try to remove the null vlues

# %%
data1["PRICE"]
# Out:
# 0           $966
# 1           $142
# 2           $620
# 4           $204
# 5           $577
#            ...
# 102053      $696
# 102054      $909
# 102055      $387
# 102056      $848
# 102057    $1,128
# Name: PRICE, Length: 101808, dtype: object

# %%
data1["PRICE"].isnull().sum() # i know how many data present  in the null values
# Out:
# np.int64(244)

# %%
data1["PRICE"].str.replace("$","")

# %%
type(data1["PRICE"][101808])
# Out:
# str

# %% [markdown]
#  # WHO TO COUVERT INTO DATA TYPE IN THE COLUMNS

# %%
data1["PRICE"]=data1["PRICE"].str.replace("$","")

# %%
data1
# Out:
#               ID                                              NAME  \
# 0        1001254                Clean & quiet apt home by the park
# 1        1002102                             Skylit Midtown Castle
# 2        1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4        1003689  Entire Apt: Spacious Studio/Loft by central park
# 5        1004098         Large Cozy 1 BR Apartment In Midtown East
# ...          ...                                               ...
# 102053  57365208               Cozy bright room near Prospect Park
# 102054  57365760         Private Bedroom with Amazing Rooftop View
# 102055  57366313     Pretty Brooklyn One-Bedroom for 2 to 4 people
# 102056  57366865        Room & private bathroom in historic Harlem
# 102057  57367417                                   Rosalee Stewart
#
#             HOST ID HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP  \
# 0       80014485718            UNCONFIRMED  Madaline            Brooklyn
# ...

# %%
data1["PRICE"]
# Out:
# 0           966
# 1           142
# 2           620
# 4           204
# 5           577
#            ...
# 102053      696
# 102054      909
# 102055      387
# 102056      848
# 102057    1,128
# Name: PRICE, Length: 101808, dtype: object

# %%
# agan replace the "," ,"" form so (1,128 )
# so

# %%
data1["PRICE"]=data["PRICE"].str.replace(",","")

# %%
data1["PRICE"]
# Out:
# 0          966
# 1          142
# 2          620
# 4          204
# 5          577
#           ...
# 102053     696
# 102054     909
# 102055     387
# 102056     848
# 102057    1128
# Name: PRICE, Length: 101808, dtype: object

# %%
data1["PRICE"][19] # the data point present in the space to remove
# Out:
# '1095 '

# %%
data1["PRICE"]=data1["PRICE"].str.replace(" ","")

# %%
data1["PRICE"]
# Out:
# 0          966
# 1          142
# 2          620
# 4          204
# 5          577
#           ...
# 102053     696
# 102054     909
# 102055     387
# 102056     848
# 102057    1128
# Name: PRICE, Length: 101808, dtype: object

# %%
data1
# Out:
#               ID                                              NAME  \
# 0        1001254                Clean & quiet apt home by the park
# 1        1002102                             Skylit Midtown Castle
# 2        1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4        1003689  Entire Apt: Spacious Studio/Loft by central park
# 5        1004098         Large Cozy 1 BR Apartment In Midtown East
# ...          ...                                               ...
# 102053  57365208               Cozy bright room near Prospect Park
# 102054  57365760         Private Bedroom with Amazing Rooftop View
# 102055  57366313     Pretty Brooklyn One-Bedroom for 2 to 4 people
# 102056  57366865        Room & private bathroom in historic Harlem
# 102057  57367417                                   Rosalee Stewart
#
#             HOST ID HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP  \
# 0       80014485718            UNCONFIRMED  Madaline            Brooklyn
# ...

# %%
data1["PRICE"][90]
# Out:
# '266'

# %%
# after that cheak the data type of the columns 
type(data1["PRICE"][8]) # data presnt in the nuerical form
# Out:
# str

# %%
# before data type convert to reMOVE the null value

# %%
data1=data1.dropna(subset=["PRICE"])
data1["PRICE"].isnull().sum()
# Out:
# np.int64(0)

# %%
data1
# Out:
#               ID                                              NAME  \
# 0        1001254                Clean & quiet apt home by the park
# 1        1002102                             Skylit Midtown Castle
# 2        1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4        1003689  Entire Apt: Spacious Studio/Loft by central park
# 5        1004098         Large Cozy 1 BR Apartment In Midtown East
# ...          ...                                               ...
# 102053  57365208               Cozy bright room near Prospect Park
# 102054  57365760         Private Bedroom with Amazing Rooftop View
# 102055  57366313     Pretty Brooklyn One-Bedroom for 2 to 4 people
# 102056  57366865        Room & private bathroom in historic Harlem
# 102057  57367417                                   Rosalee Stewart
#
#             HOST ID HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP  \
# 0       80014485718            UNCONFIRMED  Madaline            Brooklyn
# ...

# %%
type(data1["PRICE"][8])
# Out:
# str

# %%
#and the convert into the datatype
data1["PRICE"].astype(int)
# Out:
# 0          966
# 1          142
# 2          620
# 4          204
# 5          577
#           ...
# 102053     696
# 102054     909
# 102055     387
# 102056     848
# 102057    1128
# Name: PRICE, Length: 101564, dtype: int64

# %%
 # whitch type throught convert the data type
data1["PRICE"].astype(int)
# Out:
# 0          966
# 1          142
# 2          620
# 4          204
# 5          577
#           ...
# 102053     696
# 102054     909
# 102055     387
# 102056     848
# 102057    1128
# Name: PRICE, Length: 101564, dtype: int64

# %%
data1["PRICE"]=data1["PRICE"].astype(int)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101564 entries, 0 to 102057
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ID                      101564 non-null  int64
#  1   NAME                    101564 non-null  object
#  2   HOST ID                 101564 non-null  int64
#  3   HOST_IDENTITY_VERIFIED  101291 non-null  object
#  4   HOST NAME               101171 non-null  object
#  5   NEIGHBOURHOOD GROUP     101538 non-null  object
#  6   NEIGHBOURHOOD           101549 non-null  object
#  7   LAT                     101556 non-null  float64
#  8   LONG                    101556 non-null  float64
#  9   COUNTRY                 101042 non-null  object
#  10  COUNTRY CODE            101446 non-null  object
#  11  INSTANT_BOOKABLE        101564 non-null  int64
#  12  CANCELLATION_POLICY     101498 non-null  object
#  13  ROOM TYPE               101564 non-null  object
# ...

# %%
data1.isnull().sum()
# Out:
# ID                          0
# NAME                        0
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    273
# HOST NAME                 393
# NEIGHBOURHOOD GROUP        26
# NEIGHBOURHOOD              15
# LAT                         8
# LONG                        8
# COUNTRY                   522
# COUNTRY CODE              118
# INSTANT_BOOKABLE            0
# CANCELLATION_POLICY        66
# ROOM TYPE                   0
# CONSTRUCTION YEAR         201
# PRICE                       0
# SERVICE FEE               239
# MINIMUM NIGHTS            394
# NUMBER OF REVIEWS         182
# LAST REVIEW                 0
# dtype: int64

# %%
# now to clean the data the columns name (SERVICE FEE )
data1["SERVICE FEE"]
data1["SERVICE FEE"].isnull().sum()
# Out:
# np.int64(239)

# %%
# first of remove the null values
data1=data1.dropna(subset=["SERVICE FEE"])

# %%
data1["SERVICE FEE"].isnull().sum()
# Out:
# np.int64(0)

# %%
data1["SERVICE FEE"] #to remove the $ sine
# Out:
# 0         $193
# 1          $28
# 2         $124
# 4          $41
# 5         $115
#           ...
# 102040    $196
# 102041    $189
# 102042    $141
# 102043    $209
# 102044    $162
# Name: SERVICE FEE, Length: 101325, dtype: object

# %%
data1["SERVICE FEE"]=data1["SERVICE FEE"].str.replace("$","")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/1148079174.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["SERVICE FEE"]=data1["SERVICE FEE"].str.replace("$","")

# %%
data1["SERVICE FEE"][23]# to remove the "," , "" form
# Out:
# '210 '

# %%
data1["SERVICE FEE"]=data1["SERVICE FEE"].str.replace(",","")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/2345004011.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["SERVICE FEE"]=data1["SERVICE FEE"].str.replace(",","")

# %%
data1["SERVICE FEE"][9] # to remove the " " , "" form ('58 ')
# Out:
# '58 '

# %%
data1["SERVUCE FEE"]=data1["SERVICE FEE"].str.replace(" ","")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/3377543925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["SERVUCE FEE"]=data1["SERVICE FEE"].str.replace(" ","")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101325 entries, 0 to 102044
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ID                      101325 non-null  int64
#  1   NAME                    101325 non-null  object
#  2   HOST ID                 101325 non-null  int64
#  3   HOST_IDENTITY_VERIFIED  101053 non-null  object
#  4   HOST NAME               100932 non-null  object
#  5   NEIGHBOURHOOD GROUP     101299 non-null  object
#  6   NEIGHBOURHOOD           101310 non-null  object
#  7   LAT                     101317 non-null  float64
#  8   LONG                    101317 non-null  float64
#  9   COUNTRY                 100803 non-null  object
#  10  COUNTRY CODE            101211 non-null  object
#  11  INSTANT_BOOKABLE        101325 non-null  int64
#  12  CANCELLATION_POLICY     101259 non-null  object
#  13  ROOM TYPE               101325 non-null  object
# ...

# %%
data1.isnull().sum()
# Out:
# ID                          0
# NAME                        0
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    272
# HOST NAME                 393
# NEIGHBOURHOOD GROUP        26
# NEIGHBOURHOOD              15
# LAT                         8
# LONG                        8
# COUNTRY                   522
# COUNTRY CODE              114
# INSTANT_BOOKABLE            0
# CANCELLATION_POLICY        66
# ROOM TYPE                   0
# CONSTRUCTION YEAR         195
# PRICE                       0
# SERVICE FEE                 0
# MINIMUM NIGHTS            394
# NUMBER OF REVIEWS         182
# LAST REVIEW                 0
# SERVUCE FEE                 0
# dtype: int64

# %%
type(data1["SERVICE FEE"][89]) #now data type type convert into null vlaues
# Out:
# str

# %%
data1["SERVICE FEE"]=data1["SERVICE FEE"].astype(int)
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/384460379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["SERVICE FEE"]=data1["SERVICE FEE"].astype(int)

# %%
type(data1["SERVICE FEE"][90])
# Out:
# numpy.int64

# %% [raw]
# data1

# %%
data1["SERVICE FEE"].isnull().sum()
# Out:
# np.int64(0)

# %%
# 1️⃣ Simple value से fill करना
# data1["Age"] = data1["Age"].fillna(0)

# 👉 जहाँ null है वहाँ 0 आ जाएगा

# ✔️ 2️⃣ Mean (average) से fill (numeric data के लिए best)
# data1["Age"] = data1["Age"].fillna(data1["Age"].mean())
# ✔️ 3️⃣ Median से fill (outliers हों तो best)
# data1["Age"] = data1["Age"].fillna(data1["Age"].median())
# ✔️ 4️⃣ Mode से fill (categorical data के लिए)
# data1["Name"] = data1["Name"].fillna(data1["Name"].mode()[0])
# ✔️ 5️⃣ Forward Fill (previous value से)
# data1["Name"] = data1["Name"].ffill()
# ✔️ 6️⃣ Backward Fill (next value से)
# data1["Name"] = data1["Name"].bfill()
# ✔️ 7️⃣ Custom value (like "Unknown")
# data1["Name"] = data1["Name"].fillna("Unknown")

# %%
# to work in the in this columns(CONSTRUCTION YEAR)
data1["CONSTRUCTION YEAR"].isnull().sum()
# Out:
# np.int64(195)

# %%
data1["CONSTRUCTION YEAR"]=data1["CONSTRUCTION YEAR"].fillna(data1["CONSTRUCTION YEAR"].mean())
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/4284592466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["CONSTRUCTION YEAR"]=data1["CONSTRUCTION YEAR"].fillna(data1["CONSTRUCTION YEAR"].mean())

# %%
# to work in the in this columns(CONSTRUCTION YEAR)
# Out:
# np.int64(195)

# %%
data1.isnull().sum()
# Out:
# ID                          0
# NAME                        0
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    272
# HOST NAME                 393
# NEIGHBOURHOOD GROUP        26
# NEIGHBOURHOOD              15
# LAT                         8
# LONG                        8
# COUNTRY                   522
# COUNTRY CODE              114
# INSTANT_BOOKABLE            0
# CANCELLATION_POLICY        66
# ROOM TYPE                   0
# CONSTRUCTION YEAR           0
# PRICE                       0
# SERVICE FEE                 0
# MINIMUM NIGHTS            394
# NUMBER OF REVIEWS         182
# LAST REVIEW                 0
# SERVUCE FEE                 0
# dtype: int64

# %%
data1["CONSTRUCTION YEAR"].info() #float64 convert the data type() so
# Out:
# <class 'pandas.core.series.Series'>
# Index: 101325 entries, 0 to 102044
# Series name: CONSTRUCTION YEAR
# Non-Null Count   Dtype
# --------------   -----
# 101325 non-null  float64
# dtypes: float64(1)
# memory usage: 5.6 MB

# %%
data1["CONSTRUCTION YEAR"]=data1["CONSTRUCTION YEAR"].astype(int)
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/2955510163.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["CONSTRUCTION YEAR"]=data1["CONSTRUCTION YEAR"].astype(int)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101325 entries, 0 to 102044
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ID                      101325 non-null  int64
#  1   NAME                    101325 non-null  object
#  2   HOST ID                 101325 non-null  int64
#  3   HOST_IDENTITY_VERIFIED  101053 non-null  object
#  4   HOST NAME               100932 non-null  object
#  5   NEIGHBOURHOOD GROUP     101299 non-null  object
#  6   NEIGHBOURHOOD           101310 non-null  object
#  7   LAT                     101317 non-null  float64
#  8   LONG                    101317 non-null  float64
#  9   COUNTRY                 100803 non-null  object
#  10  COUNTRY CODE            101211 non-null  object
#  11  INSTANT_BOOKABLE        101325 non-null  int64
#  12  CANCELLATION_POLICY     101259 non-null  object
#  13  ROOM TYPE               101325 non-null  object
# ...

# %%
# ✔️ तरीका 1 (Best 👍) → DateTime में convert करो
# data1["Year"] = pd.to_datetime(data1["Year"], format="%Y")
# 🔍 Result:
# 2020 → 2020-01-01
# datatype → datetime64[ns]
# ✔️ तरीका 2 → सिर्फ int रहने दो (simple)
# # Already correct
# data1["Year"] = data1["Year"]

# 👉 अगर सिर्फ analysis करना है → int भी perfectly fine है ✅

# ✔️ तरीका 3 (अगर date से year निकालना हो):
# data1["Year"] = pd.to_datetime(data1["Date"]).dt.year

# %%
data1["CONSTRUCTION YEAR"]=pd.to_datetime(data1["CONSTRUCTION YEAR"],format="%Y")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/4067012163.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["CONSTRUCTION YEAR"]=pd.to_datetime(data1["CONSTRUCTION YEAR"],format="%Y")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101325 entries, 0 to 102044
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ID                      101325 non-null  int64
#  1   NAME                    101325 non-null  object
#  2   HOST ID                 101325 non-null  int64
#  3   HOST_IDENTITY_VERIFIED  101053 non-null  object
#  4   HOST NAME               100932 non-null  object
#  5   NEIGHBOURHOOD GROUP     101299 non-null  object
#  6   NEIGHBOURHOOD           101310 non-null  object
#  7   LAT                     101317 non-null  float64
#  8   LONG                    101317 non-null  float64
#  9   COUNTRY                 100803 non-null  object
#  10  COUNTRY CODE            101211 non-null  object
#  11  INSTANT_BOOKABLE        101325 non-null  int64
#  12  CANCELLATION_POLICY     101259 non-null  object
#  13  ROOM TYPE               101325 non-null  object
# ...

# %%
data1.isnull().sum()
# Out:
# ID                          0
# NAME                        0
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    272
# HOST NAME                 393
# NEIGHBOURHOOD GROUP        26
# NEIGHBOURHOOD              15
# LAT                         8
# LONG                        8
# COUNTRY                   522
# COUNTRY CODE              114
# INSTANT_BOOKABLE            0
# CANCELLATION_POLICY        66
# ROOM TYPE                   0
# CONSTRUCTION YEAR           0
# PRICE                       0
# SERVICE FEE                 0
# MINIMUM NIGHTS            394
# NUMBER OF REVIEWS         182
# LAST REVIEW                 0
# SERVUCE FEE                 0
# dtype: int64

# %%
# work in the columns (HOST_IDENTITY_VERIFIED)
data1["HOST_IDENTITY_VERIFIED"].value_counts()
# Out:
# HOST_IDENTITY_VERIFIED
# UNCONFIRMED    50597
# VERIFIED       50456
# Name: count, dtype: int64

# %%
print((50597+50456)/2)
# Out:
# 50526.5

# %%
# the avrage value Acording the (UNCONFIRMED) so  i filled the value in the (UNCONFIRMED) 
# beace the nearest value thats why
# ✔️ Simple तरीका:
# data1["Name"] = data1["Name"].fillna("Unknown")

# 👉 जहाँ null होगा → वहाँ "Unknown" आ जाएगा
# 👉 बाकी data same रहेगा ✅

# After:

# data1["Name"] = data1["Name"].fillna("Not Available")

# Result:

# Ram
# Not Available
# Shyam
# Not Available
# ✔️ Multiple columns में apply:
# data1[["Name", "City"]] = data1[["Name", "City"]].fillna("Unknown")
# ✔️ Condition based (advanced 🔥):
# data1.loc[data1["Name"].isnull(), "Name"] = "Missing"
# ⚡ Pro Tip (Data Analyst 🚀):
# data1.select_dtypes(include="object").fillna("Unknown", inplace=True)

# %%
data1["HOST_IDENTITY_VERIFIED"]=data1["HOST_IDENTITY_VERIFIED"].fillna("UNCONFIRMED")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/3804419763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["HOST_IDENTITY_VERIFIED"]=data1["HOST_IDENTITY_VERIFIED"].fillna("UNCONFIRMED")

# %%
data1.isnull().sum()
# Out:
# ID                          0
# NAME                        0
# HOST ID                     0
# HOST_IDENTITY_VERIFIED      0
# HOST NAME                 393
# NEIGHBOURHOOD GROUP        26
# NEIGHBOURHOOD              15
# LAT                         8
# LONG                        8
# COUNTRY                   522
# COUNTRY CODE              114
# INSTANT_BOOKABLE            0
# CANCELLATION_POLICY        66
# ROOM TYPE                   0
# CONSTRUCTION YEAR           0
# PRICE                       0
# SERVICE FEE                 0
# MINIMUM NIGHTS            394
# NUMBER OF REVIEWS         182
# LAST REVIEW                 0
# SERVUCE FEE                 0
# dtype: int64

# %%
data1["HOST_IDENTITY_VERIFIED"]
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 2         UNCONFIRMED
# 4            VERIFIED
# 5            VERIFIED
#              ...
# 102040       VERIFIED
# 102041       VERIFIED
# 102042       VERIFIED
# 102043       VERIFIED
# 102044       VERIFIED
# Name: HOST_IDENTITY_VERIFIED, Length: 101325, dtype: object

# %%
 # the column work in the (HOST NAME) columns

# %%
data1["HOST NAME"].value_counts().head(900)

data1=data1.dropna(subset=["HOST NAME"])

# %%
data1["HOST NAME"].isnull().sum()
# Out:
# np.int64(0)

# %%
data1.isnull().sum()
# Out:
# ID                          0
# NAME                        0
# HOST ID                     0
# HOST_IDENTITY_VERIFIED      0
# HOST NAME                   0
# NEIGHBOURHOOD GROUP        25
# NEIGHBOURHOOD              15
# LAT                         8
# LONG                        8
# COUNTRY                   521
# COUNTRY CODE              113
# INSTANT_BOOKABLE            0
# CANCELLATION_POLICY        65
# ROOM TYPE                   0
# CONSTRUCTION YEAR           0
# PRICE                       0
# SERVICE FEE                 0
# MINIMUM NIGHTS            394
# NUMBER OF REVIEWS         182
# LAST REVIEW                 0
# SERVUCE FEE                 0
# dtype: int64

# %%
# know i am woring in the  columns name (COUNTRY ) columns

# %%
data1["COUNTRY"].value_counts()
# Out:
# COUNTRY
# United States    100411
# Name: count, dtype: int64

# %%
 # its information only ye patha chalta hay ki only one  COUNTRY thats why null value fill in the United States
# United States fillna

# %%
data1["COUNTRY"]=data1["COUNTRY"].fillna("United States")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/2851742073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["COUNTRY"]=data1["COUNTRY"].fillna("United States")

# %%
data1["COUNTRY"].value_counts()
# Out:
# COUNTRY
# United States    100932
# Name: count, dtype: int64

# %%
data1["COUNTRY"].isnull().sum() # the counry column work aprox done
# Out:
# np.int64(0)

# %%
data1.isnull().sum()
# Out:
# ID                          0
# NAME                        0
# HOST ID                     0
# HOST_IDENTITY_VERIFIED      0
# HOST NAME                   0
# NEIGHBOURHOOD GROUP        25
# NEIGHBOURHOOD              15
# LAT                         8
# LONG                        8
# COUNTRY                     0
# COUNTRY CODE              113
# INSTANT_BOOKABLE            0
# CANCELLATION_POLICY        65
# ROOM TYPE                   0
# CONSTRUCTION YEAR           0
# PRICE                       0
# SERVICE FEE                 0
# MINIMUM NIGHTS            394
# NUMBER OF REVIEWS         182
# LAST REVIEW                 0
# SERVUCE FEE                 0
# dtype: int64

# %%
data1.head(2)
# Out:
#         ID                                NAME      HOST ID  \
# 0  1001254  Clean & quiet apt home by the park  80014485718
# 1  1002102               Skylit Midtown Castle  52335172823
#
#   HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP NEIGHBOURHOOD  \
# 0            UNCONFIRMED  Madaline            Brooklyn    Kensington
# 1               VERIFIED     Jenna           Manhattan       Midtown
#
#         LAT      LONG        COUNTRY  ... INSTANT_BOOKABLE  \
# 0  40.64749 -73.97237  United States  ...                0
# 1  40.75362 -73.98377  United States  ...                0
#
#    CANCELLATION_POLICY        ROOM TYPE CONSTRUCTION YEAR PRICE  SERVICE FEE  \
# 0               strict     Private room        2020-01-01   966          193
# 1             moderate  Entire home/apt        2007-01-01   142           28
#
#    MINIMUM NIGHTS  NUMBER OF REVIEWS  LAST REVIEW SERVUCE FEE
# 0            10.0                9.0   10/19/2021         193
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100932 entries, 0 to 102040
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ID                      100932 non-null  int64
#  1   NAME                    100932 non-null  object
#  2   HOST ID                 100932 non-null  int64
#  3   HOST_IDENTITY_VERIFIED  100932 non-null  object
#  4   HOST NAME               100932 non-null  object
#  5   NEIGHBOURHOOD GROUP     100907 non-null  object
#  6   NEIGHBOURHOOD           100917 non-null  object
#  7   LAT                     100924 non-null  float64
#  8   LONG                    100924 non-null  float64
#  9   COUNTRY                 100932 non-null  object
#  10  COUNTRY CODE            100819 non-null  object
#  11  INSTANT_BOOKABLE        100932 non-null  int64
#  12  CANCELLATION_POLICY     100867 non-null  object
#  13  ROOM TYPE               100932 non-null  object
# ...

# %%
# 17  MINIMUM NIGHTS          100538 non-null  float64       
#  18  NUMBER OF REVIEWS       100750 non-null  float64
# first the working in the(MINIMUM NIGHTS) columns tha
data1["MINIMUM NIGHTS"].isnull().sum()
# Out:
# np.int64(394)

# %%
data1["MINIMUM NIGHTS"]=data1["MINIMUM NIGHTS"].fillna(data1["MINIMUM NIGHTS"].mean())
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/1157848307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["MINIMUM NIGHTS"]=data1["MINIMUM NIGHTS"].fillna(data1["MINIMUM NIGHTS"].mean())

# %%
data1["MINIMUM NIGHTS"].isnull().sum()
# Out:
# np.int64(0)

# %%
type(data1["MINIMUM NIGHTS"][90000])
# Out:
# numpy.float64

# %%
# the data convert float64 to the int64

# %%
data1["MINIMUM NIGHTS"]=data1["MINIMUM NIGHTS"].astype(int)
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/1310696708.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["MINIMUM NIGHTS"]=data1["MINIMUM NIGHTS"].astype(int)

# %%
type(data1["MINIMUM NIGHTS"][90])
# Out:
# numpy.int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100932 entries, 0 to 102040
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ID                      100932 non-null  int64
#  1   NAME                    100932 non-null  object
#  2   HOST ID                 100932 non-null  int64
#  3   HOST_IDENTITY_VERIFIED  100932 non-null  object
#  4   HOST NAME               100932 non-null  object
#  5   NEIGHBOURHOOD GROUP     100907 non-null  object
#  6   NEIGHBOURHOOD           100917 non-null  object
#  7   LAT                     100924 non-null  float64
#  8   LONG                    100924 non-null  float64
#  9   COUNTRY                 100932 non-null  object
#  10  COUNTRY CODE            100819 non-null  object
#  11  INSTANT_BOOKABLE        100932 non-null  int64
#  12  CANCELLATION_POLICY     100867 non-null  object
#  13  ROOM TYPE               100932 non-null  object
# ...

# %%
# now the working in the columns in the # NUMBER OF REVIEWS

# %%
data1["NUMBER OF REVIEWS"].isnull().sum()
# Out:
# np.int64(182)

# %%
data1["NUMBER OF REVIEWS"]=data1["NUMBER OF REVIEWS"].fillna(data1["NUMBER OF REVIEWS"].mean())
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/1420210303.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["NUMBER OF REVIEWS"]=data1["NUMBER OF REVIEWS"].fillna(data1["NUMBER OF REVIEWS"].mean())

# %%
data1["NUMBER OF REVIEWS"].isnull().sum()
# Out:
# np.int64(0)

# %%
data1.isnull().sum()
# Out:
# ID                          0
# NAME                        0
# HOST ID                     0
# HOST_IDENTITY_VERIFIED      0
# HOST NAME                   0
# NEIGHBOURHOOD GROUP        25
# NEIGHBOURHOOD              15
# LAT                         8
# LONG                        8
# COUNTRY                     0
# COUNTRY CODE              113
# INSTANT_BOOKABLE            0
# CANCELLATION_POLICY        65
# ROOM TYPE                   0
# CONSTRUCTION YEAR           0
# PRICE                       0
# SERVICE FEE                 0
# MINIMUM NIGHTS              0
# NUMBER OF REVIEWS           0
# LAST REVIEW                 0
# SERVUCE FEE                 0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100932 entries, 0 to 102040
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ID                      100932 non-null  int64
#  1   NAME                    100932 non-null  object
#  2   HOST ID                 100932 non-null  int64
#  3   HOST_IDENTITY_VERIFIED  100932 non-null  object
#  4   HOST NAME               100932 non-null  object
#  5   NEIGHBOURHOOD GROUP     100907 non-null  object
#  6   NEIGHBOURHOOD           100917 non-null  object
#  7   LAT                     100924 non-null  float64
#  8   LONG                    100924 non-null  float64
#  9   COUNTRY                 100932 non-null  object
#  10  COUNTRY CODE            100819 non-null  object
#  11  INSTANT_BOOKABLE        100932 non-null  int64
#  12  CANCELLATION_POLICY     100867 non-null  object
#  13  ROOM TYPE               100932 non-null  object
# ...

# %%
data1
# Out:
#               ID                                              NAME  \
# 0        1001254                Clean & quiet apt home by the park
# 1        1002102                             Skylit Midtown Castle
# 2        1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4        1003689  Entire Apt: Spacious Studio/Loft by central park
# 5        1004098         Large Cozy 1 BR Apartment In Midtown East
# ...          ...                                               ...
# 102029  57351953            Cozy room in a 2B with backyard access
# 102030  57352505                      An East Williamsburg Delight
# 102031  57353057                      Cozy bedroom in williamsburg
# 102032  57353610                            Spacious Room w/ 2 Bed
# 102040  57358028                     Room in Queens, NY, near LGA.
#
#             HOST ID HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0       80014485718            UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
 # know i am working in the olumns name  COUNTRY CODE

# %%
data1["COUNTRY CODE"].isnull().sum()
# Out:
# np.int64(113)

# %%
data1["COUNTRY CODE"][8]
# Out:
# 'US'

# %%
data1["COUNTRY CODE"]=data1["COUNTRY CODE"].fillna("US")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/1679671617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["COUNTRY CODE"]=data1["COUNTRY CODE"].fillna("US")

# %%
data1["COUNTRY CODE"].isnull().sum()
# Out:
# np.int64(0)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100932 entries, 0 to 102040
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ID                      100932 non-null  int64
#  1   NAME                    100932 non-null  object
#  2   HOST ID                 100932 non-null  int64
#  3   HOST_IDENTITY_VERIFIED  100932 non-null  object
#  4   HOST NAME               100932 non-null  object
#  5   NEIGHBOURHOOD GROUP     100907 non-null  object
#  6   NEIGHBOURHOOD           100917 non-null  object
#  7   LAT                     100924 non-null  float64
#  8   LONG                    100924 non-null  float64
#  9   COUNTRY                 100932 non-null  object
#  10  COUNTRY CODE            100932 non-null  object
#  11  INSTANT_BOOKABLE        100932 non-null  int64
#  12  CANCELLATION_POLICY     100867 non-null  object
#  13  ROOM TYPE               100932 non-null  object
# ...

# %%
data1.isnull().sum()
# Out:
# ID                         0
# NAME                       0
# HOST ID                    0
# HOST_IDENTITY_VERIFIED     0
# HOST NAME                  0
# NEIGHBOURHOOD GROUP       25
# NEIGHBOURHOOD             15
# LAT                        8
# LONG                       8
# COUNTRY                    0
# COUNTRY CODE               0
# INSTANT_BOOKABLE           0
# CANCELLATION_POLICY       65
# ROOM TYPE                  0
# CONSTRUCTION YEAR          0
# PRICE                      0
# SERVICE FEE                0
# MINIMUM NIGHTS             0
# NUMBER OF REVIEWS          0
# LAST REVIEW                0
# SERVUCE FEE                0
# dtype: int64

# %%
# know i am working in the (CANCELLATION_POLICY) columns
data1["CANCELLATION_POLICY"].value_counts()
# Out:
# CANCELLATION_POLICY
# moderate    33787
# strict      33560
# flexible    33520
# Name: count, dtype: int64

# %%
type(data1["CANCELLATION_POLICY"][0])
# Out:
# str

# %%
print((33787+33560+33520)/3) # strict fill hoga
# Out:
# 33622.333333333336

# %%
data1["CANCELLATION_POLICY"]=data1["CANCELLATION_POLICY"].fillna("strict")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/3890640661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["CANCELLATION_POLICY"]=data1["CANCELLATION_POLICY"].fillna("strict")

# %%
data1.isnull().sum()
# Out:
# ID                         0
# NAME                       0
# HOST ID                    0
# HOST_IDENTITY_VERIFIED     0
# HOST NAME                  0
# NEIGHBOURHOOD GROUP       25
# NEIGHBOURHOOD             15
# LAT                        8
# LONG                       8
# COUNTRY                    0
# COUNTRY CODE               0
# INSTANT_BOOKABLE           0
# CANCELLATION_POLICY        0
# ROOM TYPE                  0
# CONSTRUCTION YEAR          0
# PRICE                      0
# SERVICE FEE                0
# MINIMUM NIGHTS             0
# NUMBER OF REVIEWS          0
# LAST REVIEW                0
# SERVUCE FEE                0
# dtype: int64

# %%
# know i am workingin the columns(NEIGHBOURHOOD GROUP)
data1["NEIGHBOURHOOD GROUP"].value_counts()
# Out:
# NEIGHBOURHOOD GROUP
# Manhattan        43074
# Brooklyn         41172
# Queens           13056
# Bronx             2666
# Staten Island      938
# brookln              1
# Name: count, dtype: int64

# %%
print((43074+41172+13056+2666+938+1)/5) # Brooklyn
# Out:
# 20181.4

# %%
data1["NEIGHBOURHOOD GROUP"]=data1["NEIGHBOURHOOD GROUP"].fillna("Brooklyn")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/4135686054.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["NEIGHBOURHOOD GROUP"]=data1["NEIGHBOURHOOD GROUP"].fillna("Brooklyn")

# %%
data1.isnull().sum()
# Out:
# ID                         0
# NAME                       0
# HOST ID                    0
# HOST_IDENTITY_VERIFIED     0
# HOST NAME                  0
# NEIGHBOURHOOD GROUP        0
# NEIGHBOURHOOD             15
# LAT                        8
# LONG                       8
# COUNTRY                    0
# COUNTRY CODE               0
# INSTANT_BOOKABLE           0
# CANCELLATION_POLICY        0
# ROOM TYPE                  0
# CONSTRUCTION YEAR          0
# PRICE                      0
# SERVICE FEE                0
# MINIMUM NIGHTS             0
# NUMBER OF REVIEWS          0
# LAST REVIEW                0
# SERVUCE FEE                0
# dtype: int64

# %%
# know i am workingin the columns(NEIGHBOURHOOD)
data1=data1.dropna(subset="NEIGHBOURHOOD")

# %%
data1["NEIGHBOURHOOD"]
# Out:
# 0                 Kensington
# 1                    Midtown
# 2                     Harlem
# 4                East Harlem
# 5                Murray Hill
#                  ...
# 102029               Astoria
# 102030    Bedford-Stuyvesant
# 102031          Williamsburg
# 102032               Bayside
# 102040         East Elmhurst
# Name: NEIGHBOURHOOD, Length: 100917, dtype: object

# %%
data1["NEIGHBOURHOOD"].isnull().sum()
# Out:
# np.int64(0)

# %%
data1.isnull().sum()
# Out:
# ID                        0
# NAME                      0
# HOST ID                   0
# HOST_IDENTITY_VERIFIED    0
# HOST NAME                 0
# NEIGHBOURHOOD GROUP       0
# NEIGHBOURHOOD             0
# LAT                       8
# LONG                      8
# COUNTRY                   0
# COUNTRY CODE              0
# INSTANT_BOOKABLE          0
# CANCELLATION_POLICY       0
# ROOM TYPE                 0
# CONSTRUCTION YEAR         0
# PRICE                     0
# SERVICE FEE               0
# MINIMUM NIGHTS            0
# NUMBER OF REVIEWS         0
# LAST REVIEW               0
# SERVUCE FEE               0
# dtype: int64

# %%
# LAT                       8
# LONG                      8
 # now i am working in the (LAT) columns

# %%
data1["LAT"].value_counts()
# Out:
# LAT
# 40.76411    35
# 40.71813    32
# 40.76125    27
# 40.73756    26
# 40.71353    25
#             ..
# 40.82210     1
# 40.78011     1
# 40.85754     1
# 40.83442     1
# 40.64776     1
# Name: count, Length: 21919, dtype: int64

# %%
data1["LAT"]=data1["LAT"].fillna(data1["LAT"].mean())
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/1042088598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["LAT"]=data1["LAT"].fillna(data1["LAT"].mean())

# %%
data1["LAT"].isnull().sum()
# Out:
# np.int64(0)

# %%
data1.isnull().sum()
# Out:
# ID                        0
# NAME                      0
# HOST ID                   0
# HOST_IDENTITY_VERIFIED    0
# HOST NAME                 0
# NEIGHBOURHOOD GROUP       0
# NEIGHBOURHOOD             0
# LAT                       0
# LONG                      8
# COUNTRY                   0
# COUNTRY CODE              0
# INSTANT_BOOKABLE          0
# CANCELLATION_POLICY       0
# ROOM TYPE                 0
# CONSTRUCTION YEAR         0
# PRICE                     0
# SERVICE FEE               0
# MINIMUM NIGHTS            0
# NUMBER OF REVIEWS         0
# LAST REVIEW               0
# SERVUCE FEE               0
# dtype: int64

# %%
 # now i am working in the columns(LONG )

# %%
data1["LONG"].value_counts()
# Out:
# LONG
# -73.99371    43
# -73.94791    37
# -73.95427    37
# -73.95350    37
# -73.95677    34
#              ..
# -73.97312     1
# -74.02111     1
# -73.88844     1
# -73.79474     1
# -73.81533     1
# Name: count, Length: 17707, dtype: int64

# %%
data1["LONG"]=data1["LONG"].fillna(data1["LONG"].mean())
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_15481/1431133125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["LONG"]=data1["LONG"].fillna(data1["LONG"].mean())

# %%
data1["LONG"]
# Out:
# 0        -73.97237
# 1        -73.98377
# 2        -73.94190
# 4        -73.94399
# 5        -73.97500
#             ...
# 102029   -73.92679
# 102030   -73.91222
# 102031   -73.96710
# 102032   -73.75349
# 102040   -73.87938
# Name: LONG, Length: 100917, dtype: float64

# %%
data1["LONG"].isnull().sum()
# Out:
# np.int64(0)

# %%
data1.isnull().sum()
# Out:
# ID                        0
# NAME                      0
# HOST ID                   0
# HOST_IDENTITY_VERIFIED    0
# HOST NAME                 0
# NEIGHBOURHOOD GROUP       0
# NEIGHBOURHOOD             0
# LAT                       0
# LONG                      0
# COUNTRY                   0
# COUNTRY CODE              0
# INSTANT_BOOKABLE          0
# CANCELLATION_POLICY       0
# ROOM TYPE                 0
# CONSTRUCTION YEAR         0
# PRICE                     0
# SERVICE FEE               0
# MINIMUM NIGHTS            0
# NUMBER OF REVIEWS         0
# LAST REVIEW               0
# SERVUCE FEE               0
# dtype: int64

# %%
 # finaly all data are filter data1["LONG"]
# ID                        0
# NAME                      0
# HOST ID                   0
# HOST_IDENTITY_VERIFIED    0
# HOST NAME                 0
# NEIGHBOURHOOD GROUP       0
# NEIGHBOURHOOD             0
# LAT                       0
# LONG                      0
# COUNTRY                   0
# COUNTRY CODE              0
# INSTANT_BOOKABLE          0
# CANCELLATION_POLICY       0
# ROOM TYPE                 0
# CONSTRUCTION YEAR         0
# PRICE                     0
# SERVICE FEE               0
# MINIMUM NIGHTS            0
# NUMBER OF REVIEWS         0
# LAST REVIEW               0
# SERVUCE FEE               0

# %%
data1
