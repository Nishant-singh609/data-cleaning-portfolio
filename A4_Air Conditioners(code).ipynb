# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("A4_(before cleanng_data_set)Air Conditioners.csv")

# %%
data.head()
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
#
#        sub_category                                              image  \
# 0  Air Conditioners  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  Air Conditioners  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link ratings no_of_ratings  \
# ...

# %%
data.tail()
# Out:
#                                                   name main_category  \
# 715  Personal Air Conditioners Portable AC Mini Air...    appliances
# 716  Air Conditioner Fan Personal Desk Fan Space Ai...    appliances
# 717  Portable Air Conditioners, Personal Air Condit...    appliances
# 718  Portable Air Conditioner Fan, Personal Air Coo...    appliances
# 719  Air Choice Desktop Protable AC Cooler Fan For ...    appliances
#
#          sub_category                                              image  \
# 715  Air Conditioners  https://m.media-amazon.com/images/I/71RkCzQZyd...
# 716  Air Conditioners  https://m.media-amazon.com/images/I/719ujjLfw7...
# 717  Air Conditioners  https://m.media-amazon.com/images/I/71l59r1G-J...
# 718  Air Conditioners  https://m.media-amazon.com/images/I/61GXC1nOlS...
# 719  Air Conditioners  https://m.media-amazon.com/images/I/71yqMTaaWT...
#
#                                                   link ratings no_of_ratings  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            720 non-null    str
#  1   main_category   720 non-null    str
#  2   sub_category    720 non-null    str
#  3   image           720 non-null    str
#  4   link            720 non-null    str
#  5   ratings         433 non-null    str
#  6   no_of_ratings   433 non-null    str
#  7   discount_price  457 non-null    str
#  8   actual_price    500 non-null    str
# dtypes: str(9)
# memory usage: 50.8 KB

# %%
data.columns
# Out:
# Index(['name', 'main_category', 'sub_category', 'image', 'link', 'ratings',
#        'no_of_ratings', 'discount_price', 'actual_price'],
#       dtype='str')

# %%
# to convert in the data of column in the upper case 
new_columns=[]
for i in data.columns:
    new_columns.append(i.upper())
new_columns
# Out:
# ['NAME',
#  'MAIN_CATEGORY',
#  'SUB_CATEGORY',
#  'IMAGE',
#  'LINK',
#  'RATINGS',
#  'NO_OF_RATINGS',
#  'DISCOUNT_PRICE',
#  'ACTUAL_PRICE']

# %%
data1=data.copy()

# %%
data1.columns=new_columns

# %%
data1.columns
# Out:
# Index(['NAME', 'MAIN_CATEGORY', 'SUB_CATEGORY', 'IMAGE', 'LINK', 'RATINGS',
#        'NO_OF_RATINGS', 'DISCOUNT_PRICE', 'ACTUAL_PRICE'],
#       dtype='str')

# %%
# know i am workin in the one by one columns
data1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            720 non-null    str
#  1   MAIN_CATEGORY   720 non-null    str
#  2   SUB_CATEGORY    720 non-null    str
#  3   IMAGE           720 non-null    str
#  4   LINK            720 non-null    str
#  5   RATINGS         433 non-null    str
#  6   NO_OF_RATINGS   433 non-null    str
#  7   DISCOUNT_PRICE  457 non-null    str
#  8   ACTUAL_PRICE    500 non-null    str
# dtypes: str(9)
# memory usage: 50.8 KB

# %%
data1.duplicated().sum() # the no present in the duplicate value in the columns
# Out:
# 0

# %%
# so i am working in the the one by by one columns 
data1["NAME"].value_counts()
# Out:
# NAME
# Samsung 1.5 Ton 3 Star Wind-Free Technology Inverter Split AC (Copper, Convertible 5-in-1 Cooling Mode, Anti-bacterial Fil...    3
# White Westinghouse 1.5 ton 3 Star fix Speed Split AC                                                                             3
# LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (Copper, Super Convertible 6-in-1 Cooling, HD Filter with Anti-Virus Protectio...    2
# Samsung 1.5 Ton 3 Star Wi-fi Enabled, Wind-Free Technology Inverter Split AC (Copper, Convertible 5-in-1 Cooling Mode, Ant...    2
# LG 2.0 Ton 3 Star AI DUAL Inverter Split AC (Copper, Super Convertible 6-in-1 Cooling, 4 Way Swing, HD Filter with Anti-Vi...    2
#                                                                                                                                 ..
# Efast Portable Air Conditioner, Cordless Personal Air Cooler Evaporative with 3 Speeds 7 Colors, Air Cooler for Room/Bedro...    1
# ...

# %%
j=0
for i in data1["NAME"]:
    if(i=="NaN"):
        j=j+1
print(j)
# ites note present in the null value of the columns
# Out:
# 0

# %%
# now i am working in the columns in the columns name data1["MAIN_CATEGORY"]

# %%
data1["MAIN_CATEGORY"].value_counts() # only data are present in the columns MAIN_CATEGORY
# Out:
# MAIN_CATEGORY
# appliances    720
# Name: count, dtype: int64

# %%
j=0
for i in data1["MAIN_CATEGORY"]:
    if(i=="NaN"):
        j=j+1
print(j)
# ites note present in the null value of the columns
# Out:
# 0

# %%
# now i am working in the columns in the columns name data1["SUB_CATEGORY"]

# %%
data1["SUB_CATEGORY"].value_counts()
# Out:
# SUB_CATEGORY
# Air Conditioners    720
# Name: count, dtype: int64

# %%
h=0
for i in data1["SUB_CATEGORY"]:
    if(i=="NaN"):
        h=h+1
print(h) # its not present in the null
# Out:
# 0

# %%
# now i am working in the columns in the columns name data1["IMAGEY"]

# %%
data1["IMAGE"].value_counts()
# Out:
# IMAGE
# https://m.media-amazon.com/images/I/51JFb7FctDL._AC_UL320_.jpg                                      6
# https://m.media-amazon.com/images/I/417b-AztnjL._AC_UL320_.jpg                                      5
# https://m.media-amazon.com/images/I/51hbo8yQ1EL._AC_UL320_.jpg                                      5
# https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/51v5Yi0ctkL._AC_UL320_.jpg    5
# https://m.media-amazon.com/images/I/41e6oqY5-ZL._AC_UL320_.jpg                                      4
#                                                                                                    ..
# https://m.media-amazon.com/images/I/71RkCzQZydL._AC_UL320_.jpg                                      1
# https://m.media-amazon.com/images/I/719ujjLfw7L._AC_UL320_.jpg                                      1
# https://m.media-amazon.com/images/I/71l59r1G-JL._AC_UL320_.jpg                                      1
# ...

# %%
h=0
for i in data1["IMAGE"]:
    if(i=="NaN"):
        h=h+1
print(h)
# Out:
# 0

# %%
data1["IMAGE"].isnull().sum()
# Out:
# 0

# %%
# now i am working in the columns in the columns name data1[""]

# %%
data1["LINK"]
# Out:
# 0      https://www.amazon.in/Lloyd-Inverter-Convertib...
# 1      https://www.amazon.in/LG-Convertible-Anti-Viru...
# 2      https://www.amazon.in/LG-Inverter-Convertible-...
# 3      https://www.amazon.in/LG-Convertible-Anti-Viru...
# 4      https://www.amazon.in/Carrier-Inverter-Split-C...
#                              ...
# 715    https://www.amazon.in/Personal-Conditioners-Po...
# 716    https://www.amazon.in/Conditioner-Personal-Eva...
# 717    https://www.amazon.in/Portable-Conditioners-Pe...
# 718    https://www.amazon.in/Portable-Conditioner-Per...
# 719    https://www.amazon.in/Air-Choice-Desktop-Prota...
# Name: LINK, Length: 720, dtype: str

# %%
data1["LINK"].isnull().sum()

# %%
data1["LINK"].value_counts()
# Out:
# LINK
# https://www.amazon.in/Lloyd-Inverter-Convertible-Anti-Viral-GLS18I3FWAMC/dp/B0BRKXTSBT/ref=sr_1_4?qid=1679134237&s=kitchen&sr=1-4              1
# https://www.amazon.in/LG-Convertible-Anti-Virus-Protection-RS-Q19YNZE/dp/B0BQ3MXML8/ref=sr_1_5?qid=1679134237&s=kitchen&sr=1-5                 1
# https://www.amazon.in/LG-Inverter-Convertible-protection-RS-Q13JNYE/dp/B0BPYN9JGF/ref=sr_1_6?qid=1679134237&s=kitchen&sr=1-6                   1
# https://www.amazon.in/LG-Convertible-Anti-Virus-Protection-RS-Q19JNXE/dp/B0BQ3MJ1TG/ref=sr_1_7?qid=1679134237&s=kitchen&sr=1-7                 1
# https://www.amazon.in/Carrier-Inverter-Split-Copper-Flexicool/dp/B0B67RLLJC/ref=sr_1_8?qid=1679134237&s=kitchen&sr=1-8                         1
#                                                                                                                                               ..
# ...

# %%
h=0
for i in data1["LINK"]:
    if(i=="NaN"):
        h=h+1
print(h)
# Out:
# 0

# %%
data1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            720 non-null    str
#  1   MAIN_CATEGORY   720 non-null    str
#  2   SUB_CATEGORY    720 non-null    str
#  3   IMAGE           720 non-null    str
#  4   LINK            720 non-null    str
#  5   RATINGS         433 non-null    str
#  6   NO_OF_RATINGS   433 non-null    str
#  7   DISCOUNT_PRICE  457 non-null    str
#  8   ACTUAL_PRICE    500 non-null    str
# dtypes: str(9)
# memory usage: 50.8 KB

# %%
# now i am working in the columns in the columns name data1["RATINGS"]

# %%
print(type(data1["RATINGS"][8]))
# Out:
# <class 'str'>

# %%
data1["RATINGS"].value_counts().mode()
# Out:
# 0     1
# 1     2
# 2    10
# Name: count, dtype: int64

# %%
data1["RATINGS"]=data1["RATINGS"].fillna(data1["RATINGS"].mode()[0])

# %%
data1["RATINGS"].isnull().sum()
# Out:
# 0

# %%
data1["RATINGS"].value_counts()
# Out:
# RATINGS
# 4.0    343
# 4.1     41
# 5.0     41
# 4.2     38
# 3.9     29
# 4.3     19
# 3.5     18
# 3.6     18
# 3.7     16
# 3.0     16
# 3.4     15
# 3.8     13
# 3.2     13
# 3.3     12
# 1.0     12
# 4.6     10
# 4.4     10
# Get     10
# 4.5      8
# 2.5      8
# 2.7      5
# 2.8      5
# 2.9      4
# 2.6      4
# 3.1      3
# 4.7      2
# 1.8      2
# 2.4      2
# 4.8      1
# 2.3      1
# 1.7      1
# Name: count, dtype: int64

# %%
data1["RATINGS"]=data1["RATINGS"].str.replace("Get","4.4")

# %%
data1["RATINGS"].value_counts()
# Out:
# RATINGS
# 4.0    343
# 4.1     41
# 5.0     41
# 4.2     38
# 3.9     29
# 4.4     20
# 4.3     19
# 3.5     18
# 3.6     18
# 3.7     16
# 3.0     16
# 3.4     15
# 3.8     13
# 3.2     13
# 3.3     12
# 1.0     12
# 4.6     10
# 4.5      8
# 2.5      8
# 2.7      5
# 2.8      5
# 2.9      4
# 2.6      4
# 3.1      3
# 4.7      2
# 1.8      2
# 2.4      2
# 4.8      1
# 2.3      1
# 1.7      1
# Name: count, dtype: int64

# %%
data1["RATINGS"].isnull().sum()
# Out:
# 0

# %%
# type conversion in the data columns  data1["RATINGS"]

# %%
data1["RATINGS"]=data1["RATINGS"].astype(float)

# %%
data1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            720 non-null    str
#  1   MAIN_CATEGORY   720 non-null    str
#  2   SUB_CATEGORY    720 non-null    str
#  3   IMAGE           720 non-null    str
#  4   LINK            720 non-null    str
#  5   RATINGS         720 non-null    float64
#  6   NO_OF_RATINGS   433 non-null    str
#  7   DISCOUNT_PRICE  457 non-null    str
#  8   ACTUAL_PRICE    500 non-null    str
# dtypes: float64(1), str(8)
# memory usage: 50.8 KB

# %%
data1.isnull().sum()
# Out:
# NAME                0
# MAIN_CATEGORY       0
# SUB_CATEGORY        0
# IMAGE               0
# LINK                0
# RATINGS             0
# NO_OF_RATINGS     287
# DISCOUNT_PRICE    263
# ACTUAL_PRICE      220
# dtype: int64

# %%
data1["NO_OF_RATINGS"]
# Out:
# 0      2,255
# 1      2,948
# 2      1,206
# 3         69
# 4        630
#        ...
# 715      NaN
# 716      NaN
# 717      NaN
# 718      207
# 719      296
# Name: NO_OF_RATINGS, Length: 720, dtype: str

# %%
data1["NO_OF_RATINGS"][0]
# Out:
# '2,255'

# %%
data1["NO_OF_RATINGS"]=data1["NO_OF_RATINGS"].str.replace(",","")

# %%
data1["NO_OF_RATINGS"]
# Out:
# 0      2255
# 1      2948
# 2      1206
# 3        69
# 4       630
#        ...
# 715     NaN
# 716     NaN
# 717     NaN
# 718     207
# 719     296
# Name: NO_OF_RATINGS, Length: 720, dtype: str

# %%
data1["NO_OF_RATINGS"].value_counts().median()
# Out:
# 1.0

# %%
data1["NO_OF_RATINGS"]=data1["NO_OF_RATINGS"].fillna("1")

# %%
data1["NO_OF_RATINGS"].value_counts().iloc[60:90]
# Out:
# NO_OF_RATINGS
# 1666    1
# 1097    1
# 1494    1
# 674     1
# 801     1
# 558     1
# 730     1
# 5073    1
# 568     1
# 3670    1
# 268     1
# 700     1
# 540     1
# 2178    1
# 1444    1
# 360     1
# 1208    1
# 341     1
# 925     1
# 3604    1
# 42      1
# 94      1
# 1866    1
# 292     1
# 1830    1
# 536     1
# 201     1
# 2722    1
# 202     1
# 1195    1
# Name: count, dtype: int64

# %%
data1["NO_OF_RATINGS"]=data1["NO_OF_RATINGS"].str.replace(" ","")

# %%
data1["NO_OF_RATINGS"]=data1["NO_OF_RATINGS"].str.replace('Only2leftinstock.',"2")

# %%
data1["NO_OF_RATINGS"]
# Out:
# 0      2255
# 1      2948
# 2      1206
# 3        69
# 4       630
#        ...
# 715       1
# 716       1
# 717       1
# 718     207
# 719     296
# Name: NO_OF_RATINGS, Length: 720, dtype: int64

# %%
data1["NO_OF_RATINGS"]=data1["NO_OF_RATINGS"].astype(int)

# %%
import re

def clean_stock(x):
    num = re.findall(r'\d+', str(x))
    
    if len(num) > 0:
        return int(num[0])
    else:
        return 0

data1["NO_OF_RATINGS"] = data1["NO_OF_RATINGS"].apply(clean_stock)

# %%
data1["NO_OF_RATINGS"]=data1["NO_OF_RATINGS"].astype(int)

# %%
data1["NO_OF_RATINGS"]
# Out:
# 0      2255
# 1      2948
# 2      1206
# 3        69
# 4       630
#        ...
# 715       1
# 716       1
# 717       1
# 718     207
# 719     296
# Name: NO_OF_RATINGS, Length: 720, dtype: int64

# %%
data1
# Out:
#                                                   NAME MAIN_CATEGORY  \
# 0    Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1    LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2    LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3    LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4    Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# ..                                                 ...           ...
# 715  Personal Air Conditioners Portable AC Mini Air...    appliances
# 716  Air Conditioner Fan Personal Desk Fan Space Ai...    appliances
# 717  Portable Air Conditioners, Personal Air Condit...    appliances
# 718  Portable Air Conditioner Fan, Personal Air Coo...    appliances
# 719  Air Choice Desktop Protable AC Cooler Fan For ...    appliances
#
#          SUB_CATEGORY                                              IMAGE  \
# ...

# %%
data1["DISCOUNT_PRICE"]
# Out:
# 0      ₹32,999
# 1      ₹46,490
# 2      ₹34,490
# 3      ₹37,990
# 4      ₹34,490
#         ...
# 715    ₹10,234
# 716        NaN
# 717        NaN
# 718        NaN
# 719        NaN
# Name: DISCOUNT_PRICE, Length: 720, dtype: str

# %%
data1["DISCOUNT_PRICE"][90]
# Out:
# '₹48,000'

# %%
data1["DISCOUNT_PRICE"]=data1["DISCOUNT_PRICE"].str.replace("₹","")

# %%
data1["DISCOUNT_PRICE"]=data1["DISCOUNT_PRICE"].str.replace(",","")

# %%
f=data1["DISCOUNT_PRICE"]

# %%
k=f.dropna()

# %%
k.astype(int).median()
# Out:
# 39190.0

# %%
k.astype(int).mean()
# Out:
# 40756.00656455142

# %%
k.astype(int).mode()
# Out:
# 0    39990
# Name: DISCOUNT_PRICE, dtype: int64

# %%
data1["DISCOUNT_PRICE"]=data1["DISCOUNT_PRICE"].fillna("40756")

# %%
data1["DISCOUNT_PRICE"]=data1["DISCOUNT_PRICE"].astype(int)

# %%
data1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            720 non-null    str
#  1   MAIN_CATEGORY   720 non-null    str
#  2   SUB_CATEGORY    720 non-null    str
#  3   IMAGE           720 non-null    str
#  4   LINK            720 non-null    str
#  5   RATINGS         720 non-null    float64
#  6   NO_OF_RATINGS   720 non-null    int64
#  7   DISCOUNT_PRICE  720 non-null    int64
#  8   ACTUAL_PRICE    500 non-null    str
# dtypes: float64(1), int64(2), str(6)
# memory usage: 50.8 KB

# %%
# koow i am working in the columns in the data1["ACTUAL_PRICE"]

# %%
data1["ACTUAL_PRICE"]
# Out:
# 0      ₹58,990
# 1      ₹75,990
# 2      ₹61,990
# 3      ₹68,990
# 4      ₹67,790
#         ...
# 715    ₹13,999
# 716     ₹9,881
# 717     ₹6,361
# 718     ₹7,671
# 719     ₹8,592
# Name: ACTUAL_PRICE, Length: 720, dtype: str

# %%
data1["ACTUAL_PRICE"][90]
# Out:
# '₹71,750'

# %%
data1["ACTUAL_PRICE"]=data1["ACTUAL_PRICE"].str.replace('₹',"")

# %%
data1["ACTUAL_PRICE"]=data1["ACTUAL_PRICE"].str.replace(',',"")

# %%
data1["ACTUAL_PRICE"]
# Out:
# 0      58990
# 1      75990
# 2      61990
# 3      68990
# 4      67790
#        ...
# 715    13999
# 716     9881
# 717     6361
# 718     7671
# 719     8592
# Name: ACTUAL_PRICE, Length: 720, dtype: str

# %%
data1["ACTUAL_PRICE"].value_counts()
# Out:
# ACTUAL_PRICE
# 59990    15
# 55990    11
# 75990     9
# 58990     7
# 61990     7
#          ..
# 13999     1
# 9881      1
# 6361      1
# 7671      1
# 8592      1
# Name: count, Length: 296, dtype: int64

# %%
data1["ACTUAL_PRICE"].value_counts().mode().values
# Out:
# array([1])

# %%
c=data1["ACTUAL_PRICE"]

# %%
k=c.dropna()

# %%
k.astype(float).mean()
# Out:
# 54815.22724

# %%
k.astype(float).median()
# Out:
# 56990.0

# %%
data1["ACTUAL_PRICE"]=data1["ACTUAL_PRICE"].fillna("56990.0")

# %%
data1["ACTUAL_PRICE"]=data1["ACTUAL_PRICE"].astype(float)

# %%
data1["ACTUAL_PRICE"]=data1["ACTUAL_PRICE"].astype(int)

# %%
data1
# Out:
#                                                   NAME MAIN_CATEGORY  \
# 0    Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1    LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2    LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3    LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4    Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# ..                                                 ...           ...
# 715  Personal Air Conditioners Portable AC Mini Air...    appliances
# 716  Air Conditioner Fan Personal Desk Fan Space Ai...    appliances
# 717  Portable Air Conditioners, Personal Air Condit...    appliances
# 718  Portable Air Conditioner Fan, Personal Air Coo...    appliances
# 719  Air Choice Desktop Protable AC Cooler Fan For ...    appliances
#
#          SUB_CATEGORY                                              IMAGE  \
# ...

# %%
data1.to_csv("A4_(after cleanng_data_set)Air Conditioners.csv",index=False)
