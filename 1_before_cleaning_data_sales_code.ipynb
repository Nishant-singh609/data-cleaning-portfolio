# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("before_cleaning_data_sales.csv")

# %%
data.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date'],
#       dtype='object')

# %%
for i in data.columns:
    print(i)
# Out:
# Transaction ID
# Item
# Quantity
# Price Per Unit
# Total Spent
# Payment Method
# Location
# Transaction Date

# %%
print(list(data.columns))
# Out:
# ['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent', 'Payment Method', 'Location', 'Transaction Date']

# %%
  # the columns data convert into the upper case
new_col=[]
for i in data.columns:
    new_col.append(i.upper())

# %%
new_col
# Out:
# ['TRANSACTION ID',
#  'ITEM',
#  'QUANTITY',
#  'PRICE PER UNIT',
#  'TOTAL SPENT',
#  'PAYMENT METHOD',
#  'LOCATION',
#  'TRANSACTION DATE']

# %%
new_data=data.copy()

# %%
new_data.columns=new_col

# %%
new_data
# Out:
#      TRANSACTION ID      ITEM QUANTITY PRICE PER UNIT TOTAL SPENT  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       PAYMENT METHOD  LOCATION TRANSACTION DATE
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
# agarn convert the columns in lower case
new_data.columns
# Out:
# Index(['TRANSACTION ID', 'ITEM', 'QUANTITY', 'PRICE PER UNIT', 'TOTAL SPENT',
#        'PAYMENT METHOD', 'LOCATION', 'TRANSACTION DATE'],
#       dtype='object')

# %%
for i in new_data.columns:
    print(i)
# Out:
# TRANSACTION ID
# ITEM
# QUANTITY
# PRICE PER UNIT
# TOTAL SPENT
# PAYMENT METHOD
# LOCATION
# TRANSACTION DATE

# %%
list(new_data.columns)
# Out:
# ['TRANSACTION ID',
#  'ITEM',
#  'QUANTITY',
#  'PRICE PER UNIT',
#  'TOTAL SPENT',
#  'PAYMENT METHOD',
#  'LOCATION',
#  'TRANSACTION DATE']

# %%
new_data
# Out:
#      TRANSACTION ID      ITEM QUANTITY PRICE PER UNIT TOTAL SPENT  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       PAYMENT METHOD  LOCATION TRANSACTION DATE
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
# novert into into the lower case
lower=[]
for i in new_data.columns:
    lower.append(i.lower())

# %%
lower
# Out:
# ['transaction id',
#  'item',
#  'quantity',
#  'price per unit',
#  'total spent',
#  'payment method',
#  'location',
#  'transaction date']

# %%
lower_copy=new_data.copy()

# %%
lower_copy.columns=lower

# %%
lower_copy
# Out:
#      transaction id      item quantity price per unit total spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       payment method  location transaction date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
lower_copy.columns
# Out:
# Index(['transaction id', 'item', 'quantity', 'price per unit', 'total spent',
#        'payment method', 'location', 'transaction date'],
#       dtype='object')

# %%
lower_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction id    10000 non-null  object
#  1   item              9667 non-null   object
#  2   quantity          9862 non-null   object
#  3   price per unit    9821 non-null   object
#  4   total spent       9827 non-null   object
#  5   payment method    7421 non-null   object
#  6   location          6735 non-null   object
#  7   transaction date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
lower_copy.isnull().sum()
# Out:
# transaction id         0
# item                 333
# quantity             138
# price per unit       179
# total spent          173
# payment method      2579
# location            3265
# transaction date     159
# dtype: int64

# %%
# i am working in the columns (item.     ) 
lower_copy["item"].value_counts()
# Out:
# item
# Juice       1171
# Coffee      1165
# Salad       1148
# Cake        1139
# Sandwich    1131
# Smoothie    1096
# Cookie      1092
# Tea         1089
# UNKNOWN      344
# ERROR        292
# Name: count, dtype: int64

# %%
print((1171+1165+1148+1139+1131+1096+1092+1089+344+292)/10)
# Out:
# 966.7

# %%
 #966.7 "the its value the nearest in the ,"tea" data thats whty i fill the tea of null value

# %%
lower_copy["item"]=lower_copy["item"].fillna("Tea")

# %%
lower_copy["item"].value_counts().sum()
# Out:
# np.int64(10000)

# %%
lower_copy.isnull().sum()
# Out:
# transaction id         0
# item                   0
# quantity             138
# price per unit       179
# total spent          173
# payment method      2579
# location            3265
# transaction date     159
# dtype: int64

# %%
 # now i am working in the the columns lower_copy["quantity"]
lower_copy["quantity"].value_counts()
# Out:
# quantity
# 5          2013
# 2          1974
# 4          1863
# 3          1849
# 1          1822
# UNKNOWN     171
# ERROR       170
# Name: count, dtype: int64

# %%
print((2013+1974+1863+1849+1822+171+170)/7)
# Out:
# 1408.857142857143

# %%
lower_copy["quantity"]=lower_copy["quantity"].fillna(1)

# %%
lower_copy["quantity"].isnull().sum()
# Out:
# np.int64(0)

# %%
lower_copy["quantity"].value_counts()
# Out:
# quantity
# 5          2013
# 2          1974
# 4          1863
# 3          1849
# 1          1822
# UNKNOWN     171
# ERROR       170
# 1           138
# Name: count, dtype: int64

# %%
type(lower_copy["quantity"][9000])
# Out:
# str

# %%
lower_copy["quantity"]=lower_copy["quantity"].str.replace("UNKNOWN","0")

# %%
lower_copy["quantity"]=lower_copy["quantity"].str.replace("ERROR","0")

# %%
lower_copy["quantity"].value_counts()
# Out:
# quantity
# 5    2013
# 2    1974
# 4    1863
# 3    1849
# 1    1822
# 0     341
# Name: count, dtype: int64

# %%
 # to convert the data tyepe
lower_copy["quantity"].fillna
# Out:
# <bound method NDFrame.fillna of 0       2
# 1       4
# 2       4
# 3       2
# 4       2
#        ..
# 9995    2
# 9996    3
# 9997    4
# 9998    3
# 9999    3
# Name: quantity, Length: 10000, dtype: object>

# %%
lower_copy["quantity"]=lower_copy["quantity"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[651], line 1
# ----> 1 lower_copy["quantity"]=lower_copy["quantity"].astype(int)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
lower_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction id    10000 non-null  object
#  1   item              10000 non-null  object
#  2   quantity          9862 non-null   object
#  3   price per unit    9821 non-null   object
#  4   total spent       9827 non-null   object
#  5   payment method    7421 non-null   object
#  6   location          6735 non-null   object
#  7   transaction date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
lower_copy.isnull().sum()
# Out:
# transaction id         0
# item                   0
# quantity             138
# price per unit       179
# total spent          173
# payment method      2579
# location            3265
# transaction date     159
# dtype: int64

# %%
# know working in the the columns (price per unit)

# %%
lower_copy["price per unit"].isnull().sum()
# Out:
# np.int64(179)

# %%
lower_copy["price per unit"].value_counts()
# Out:
# price per unit
# 3.0        2429
# 4.0        2331
# 2.0        1227
# 5.0        1204
# 1.0        1143
# 1.5        1133
# ERROR       190
# UNKNOWN     164
# Name: count, dtype: int64

# %%
print((2429+2331+1227+1204+1143+1133)/6)
# Out:
# 1577.8333333333333

# %%
type(lower_copy["price per unit"][90])
# Out:
# str

# %%
lower_copy["price per unit"]=lower_copy["price per unit"].fillna(2.0)

# %%
lower_copy["price per unit"].value_counts()
# Out:
# price per unit
# 3.0        2429
# 4.0        2331
# 2.0        1227
# 5.0        1204
# 1.0        1143
# 1.5        1133
# ERROR       190
# 2.0         179
# UNKNOWN     164
# Name: count, dtype: int64

# %%
lower_copy["price per unit"]=lower_copy["price per unit"].str.replace("ERROR","0")

# %%
lower_copy["price per unit"]=lower_copy["price per unit"].str.replace("UNKNOWN","0")

# %%
lower_copy["price per unit"].value_counts().sum()
# Out:
# np.int64(9821)

# %%
lower_copy["price per unit"].isnull().sum()
# Out:
# np.int64(179)

# %%
lower_copy["price per unit"]=lower_copy["price per unit"].fillna(2.0)

# %%
lower_copy["price per unit"].isnull().sum()
# Out:
# np.int64(0)

# %%
lower_copy["price per unit"].value_counts()
# Out:
# price per unit
# 3.0    2429
# 4.0    2331
# 2.0    1227
# 5.0    1204
# 1.0    1143
# 1.5    1133
# 0       354
# 2.0     179
# Name: count, dtype: int64

# %%
 # To convert the data type()

# %%
lower_copy["price per unit"]=lower_copy["price per unit"].astype(float)

# %%
lower_copy["price per unit"].value_counts().sum()
# Out:
# np.int64(10000)

# %%
lower_copy["price per unit"].value_counts()
# Out:
# price per unit
# 3.0    2429
# 4.0    2331
# 2.0    1406
# 5.0    1204
# 1.0    1143
# 1.5    1133
# 0.0     354
# Name: count, dtype: int64

# %%
lower_copy["price per unit"].isnull().sum()
# Out:
# np.int64(0)

# %%
lower_copy.isnull().sum()
# Out:
# transaction id         0
# item                   0
# quantity             138
# price per unit         0
# total spent          173
# payment method      2579
# location            3265
# transaction date     159
# dtype: int64

# %%
lower_copy["quantity"].isnull().sum()
# Out:
# np.int64(138)

# %%
lower_copy["quantity"].value_counts()
# Out:
# quantity
# 5    2013
# 2    1974
# 4    1863
# 3    1849
# 1    1822
# 0     341
# Name: count, dtype: int64

# %%
print((2013+1974+1863+1849+1822+341)/6)
# Out:
# 1643.6666666666667

# %%
lower_copy["quantity"]=lower_copy["quantity"].fillna(1)

# %%
lower_copy["quantity"].value_counts()
lower_copy["quantity"].isnull().sum()
# Out:
# np.int64(0)

# %%
lower_copy["quantity"]=lower_copy["quantity"].astype(int)

# %%
lower_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction id    10000 non-null  object
#  1   item              10000 non-null  object
#  2   quantity          10000 non-null  int64
#  3   price per unit    10000 non-null  float64
#  4   total spent       9827 non-null   object
#  5   payment method    7421 non-null   object
#  6   location          6735 non-null   object
#  7   transaction date  9841 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 625.1+ KB

# %%
lower_copy.isnull().sum()
# Out:
# transaction id         0
# item                   0
# quantity               0
# price per unit         0
# total spent          173
# payment method      2579
# location            3265
# transaction date     159
# dtype: int64

# %%
# know i am working in the the column lower_copy["total spent"]

# %%
lower_copy["total spent"]
type(lower_copy["total spent"][90])
lower_copy["total spent"].value_counts()
# Out:
# total spent
# 6.0        979
# 12.0       939
# 3.0        930
# 4.0        923
# 20.0       746
# 15.0       734
# 8.0        677
# 10.0       524
# 2.0        497
# 9.0        479
# 5.0        468
# 16.0       444
# 25.0       259
# 7.5        237
# 1.0        232
# 4.5        225
# 1.5        205
# UNKNOWN    165
# ERROR      164
# Name: count, dtype: int64

# %%
lower_copy["total spent"]=lower_copy["total spent"].str.replace("UNKNOWN","0")

# %%
lower_copy["total spent"]=lower_copy["total spent"].str.replace("ERROR","0")

# %%
lower_copy["total spent"].isnull().sum()
# Out:
# np.int64(173)

# %%
print((939+930+923+746+734+677+524+497+479+468+444+329+259+237+232+225+205)/17)
# Out:
# 520.4705882352941

# %%
lower_copy["total spent"]=lower_copy["total spent"].fillna(10.0)

# %%
type(lower_copy["total spent"][0])
# Out:
# str

# %%
lower_copy["total spent"]=lower_copy["total spent"].astype(float)

# %%
lower_copy.isnull().sum()
# Out:
# transaction id         0
# item                   0
# quantity               0
# price per unit         0
# total spent            0
# payment method      2579
# location            3265
# transaction date     159
# dtype: int64

# %%
 # data are cleaning by the / lower_copy["payment method"]

# %%
lower_copy["payment method"].value_counts()
# Out:
# payment method
# Digital Wallet    2291
# Credit Card       2273
# Cash              2258
# ERROR              306
# UNKNOWN            293
# Name: count, dtype: int64

# %%
lower_copy["payment method"]=lower_copy["payment method"].str.replace("ERROR","NO_payment")

# %%
lower_copy["payment method"]=lower_copy["payment method"].str.replace("UNKNOWN","Cash")

# %%
print((2291+2273+2551+306)/4)
# Out:
# 1855.25

# %%
lower_copy["payment method"]=lower_copy["payment method"].fillna("Credit Card")

# %%
lower_copy["payment method"].isnull().sum()
# Out:
# np.int64(0)

# %%
type(lower_copy["payment method"][98])
# Out:
# str

# %%
lower_copy["payment method"]=lower_copy["payment method"].astype=(int)

# %%
lower_copy.isnull().sum()
# Out:
# transaction id         0
# item                   0
# quantity               0
# price per unit         0
# total spent            0
# payment method         0
# location            3265
# transaction date     159
# dtype: int64

# %%
# know i am koring in the the columns name lower_copy["location"]

# %%
lower_copy["location"].value_counts()

# %%
print((3022+3017)/2)
# Out:
# 3019.5

# %%
lower_copy["location"].isnull().sum()
# Out:
# np.int64(3265)

# %%
lower_copy["location"]=lower_copy["location"].str.replace("UNKNOWN","In-store")

# %%
lower_copy["location"].value_counts()
# Out:
# location
# In-store    3355
# Takeaway    3022
# ERROR        358
# Name: count, dtype: int64

# %%
lower_copy["location"]=lower_copy["location"].str.replace("ERROR","In-store")

# %%
lower_copy["location"].value_counts()
# Out:
# location
# In-store    3713
# Takeaway    3022
# Name: count, dtype: int64

# %%
print((3713+3022)/2)
# Out:
# 3367.5

# %%
lower_copy["location"]=lower_copy["location"].fillna("Takeaway")

# %%
lower_copy.isnull().sum()
# Out:
# transaction id        0
# item                  0
# quantity              0
# price per unit        0
# total spent           0
# payment method        0
# location              0
# transaction date    159
# dtype: int64

# %%
# know is the working in the lower_copy["transaction date"]

# %%
lower_copy["transaction date"].isnull().sum()
# Out:
# np.int64(159)

# %%
lower_copy["transaction date"] = lower_copy["transaction date"].fillna(method="ffill")
# Out:
# /var/folders/m5/pjzzzf8n62x495_tfwb87yrh0000gn/T/ipykernel_61898/2529941395.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   lower_copy["transaction date"] = lower_copy["transaction date"].fillna(method="ffill")

# %%
lower_copy["transaction date"].isnull().sum()
# Out:
# np.int64(0)

# %%
print((lower_copy["transaction date"].value_counts()).mean())
# Out:
# 27.3224043715847

# %%
lower_copy["transaction date"].value_counts()
# Out:
# transaction date
# UNKNOWN       160
# ERROR         144
# 2023-06-16     41
# 2023-07-21     40
# 2023-09-21     40
#              ...
# 2023-09-24     15
# 2023-04-27     15
# 2023-07-30     15
# 2023-03-11     14
# 2023-02-17     14
# Name: count, Length: 367, dtype: int64

# %%
lower_copy["transaction date"].value_counts().iloc[145:180]
# Out:
# transaction date
# 2023-09-15    28
# 2023-12-21    28
# 2023-06-09    27
# 2023-02-24    27
# 2023-10-23    27
# 2023-04-01    27
# 2023-05-08    27
# 2023-11-20    27
# 2023-02-01    27
# 2023-06-08    27
# 2023-09-05    27
# 2023-01-08    27
# 2023-11-04    27
# 2023-11-15    27
# 2023-10-03    27
# 2023-11-03    27
# 2023-03-20    27
# 2023-05-31    27
# 2023-03-24    27
# 2023-04-10    27
# 2023-01-21    27
# 2023-07-31    27
# 2023-05-04    27
# 2023-02-03    27
# 2023-12-30    27
# 2023-12-02    27
# 2023-07-15    27
# 2023-11-09    27
# 2023-01-16    27
# 2023-03-06    27
# 2023-09-09    27
# 2023-02-18    27
# 2023-01-04    27
# 2023-02-05    26
# 2023-07-19    26
# Name: count, dtype: int64

# %%
lower_copy["transaction date"]=lower_copy["transaction date"].str.replace("UNKNOWN","2023-11-20")

# %%
lower_copy["transaction date"].value_counts()
# Out:
# transaction date
# 2023-11-20    187
# ERROR         144
# 2023-06-16     41
# 2023-09-21     40
# 2023-02-06     40
#              ...
# 2023-09-24     15
# 2023-11-24     15
# 2023-07-30     15
# 2023-03-11     14
# 2023-02-17     14
# Name: count, Length: 366, dtype: int64

# %%
lower_copy["transaction date"]=lower_copy["transaction date"].str.replace("22023-11-03","2023-11-03")

# %%
lower_copy["transaction date"].value_counts()
# Out:
# transaction date
# 2023-11-20    187
# 2023-11-03    171
# 2023-06-16     41
# 2023-09-21     40
# 2023-07-21     40
#              ...
# 2023-09-24     15
# 2023-11-24     15
# 2023-07-30     15
# 2023-03-11     14
# 2023-02-17     14
# Name: count, Length: 365, dtype: int64

# %%
lower_copy["transaction date"].isnull().sum()
# Out:
# np.int64(0)

# %%
lower_copy.isnull().sum()
# Out:
# transaction id      0
# item                0
# quantity            0
# price per unit      0
# total spent         0
# payment method      0
# location            0
# transaction date    0
# dtype: int64

# %%
# fillnaly clean the data(null,error,unkown)

# %%
lower_copy.to_csv("after_cleaning_data_sales.csv")
